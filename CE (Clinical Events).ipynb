# %% [markdown]
# ### 2. Clinical events (ce.csv) - [One record per event per subject]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
# Load clinical events .csv file
possible_paths = [
    'C:/Users/lenne/OneDrive/Documenten/Master of Statistics and Data Science/2023-2024/Master thesis/MSOAC Placebo Data',
    'C:/Users/anaso/Desktop/SOFIA MENDES/KU Leuven/Master Thesis/MSOAC Placebo dataset/csv files'
]

file_name = 'ce.csv'
file_path = next(f'{path}/{file_name}' for path in possible_paths if os.path.exists(f'{path}/{file_name}'))
# Create data frame
clinical_events = pd.read_csv(file_path)

# Sort by the 'USUBJID' and 'CESEQ' columns in ascending order
clinical_events = clinical_events.sort_values(by=['USUBJID','CESEQ'], ascending=True)
clinical_events
# Out:
#      STUDYID DOMAIN     USUBJID  CESEQ  CEGRPID  CEREFID  CESPID  \
# 432    MSOAC     CE  MSOAC/0031      1      NaN      NaN     NaN
# 1334   MSOAC     CE  MSOAC/0031      2      NaN      NaN     NaN
# 1022   MSOAC     CE  MSOAC/0035      1      NaN      NaN     NaN
# 1368   MSOAC     CE  MSOAC/0035      2      NaN      NaN     NaN
# 1819   MSOAC     CE  MSOAC/0041      1      NaN      NaN     NaN
# ...      ...    ...         ...    ...      ...      ...     ...
# 1959   MSOAC     CE  MSOAC/9995      4      NaN      NaN     NaN
# 871    MSOAC     CE  MSOAC/9998      1      NaN      NaN     NaN
# 1739   MSOAC     CE  MSOAC/9998      2      NaN      NaN     NaN
# 975    MSOAC     CE  MSOAC/9999      1      NaN      NaN     NaN
# 1397   MSOAC     CE  MSOAC/9999      2      NaN      NaN     NaN
#
#                             CETERM                       CEMODIFY  \
# 432                     MS RELAPSE  Neurologist Confirmed Relapse
# 1334                    MS RELAPSE  Neurologist Confirmed Relapse
# 1022  MS RELAPSE CONFIRMED BY EDSS         EDSS Confirmed Relapse
# 1368  MS RELAPSE CONFIRMED BY EDSS         EDSS Confirmed Relapse
# 1819            MS EXACERBATION #1  MULTIPLE SCLEROSIS AGGRAVATED
# ...                            ...                            ...
# 1959        UNCONFIRMED MS RELAPSE              Suspected Relapse
# 871      Confirmed MS Exacerbation                            NaN
# 1739     Suspected MS Exacerbation                            NaN
# 975   MS RELAPSE CONFIRMED BY EDSS         EDSS Confirmed Relapse
# 1397  MS RELAPSE CONFIRMED BY EDSS         EDSS Confirmed Relapse
#
#                          CEDECOD  ... CEENDY  CESTRF   CEENRF CEEVLINT  \
# 432   MULTIPLE SCLEROSIS RELAPSE  ...  279.0     NaN      NaN      NaN
# 1334  MULTIPLE SCLEROSIS RELAPSE  ...    NaN     NaN      NaN      NaN
# 1022  MULTIPLE SCLEROSIS RELAPSE  ...    NaN     NaN      NaN      NaN
# 1368  MULTIPLE SCLEROSIS RELAPSE  ...    NaN     NaN      NaN      NaN
# 1819          MULTIPLE SCLEROSIS  ...    NaN     NaN  ONGOING      NaN
# ...                          ...  ...    ...     ...      ...      ...
# 1959          RELAPSE-LIKE EVENT  ...    NaN     NaN      NaN      NaN
# 871   MULTIPLE SCLEROSIS RELAPSE  ...    NaN     NaN      NaN      NaN
# 1739          RELAPSE-LIKE EVENT  ...    NaN     NaN      NaN      NaN
# 975   MULTIPLE SCLEROSIS RELAPSE  ...    NaN     NaN      NaN      NaN
# 1397  MULTIPLE SCLEROSIS RELAPSE  ...    NaN     NaN      NaN      NaN
#
#       CEEVINTX  CESTRTPT CESTTPT  CEENRTPT  CEENTPT          MIDS
# 432        NaN       NaN     NaN       NaN      NaN  MS RELAPSE 1
# 1334       NaN       NaN     NaN       NaN      NaN  MS RELAPSE 2
# 1022       NaN       NaN     NaN       NaN      NaN  MS RELAPSE 1
# 1368       NaN       NaN     NaN       NaN      NaN  MS RELAPSE 2
# 1819       NaN       NaN     NaN       NaN      NaN           NaN
# ...        ...       ...     ...       ...      ...           ...
# 1959       NaN       NaN     NaN       NaN      NaN           NaN
# 871        NaN       NaN     NaN       NaN      NaN  MS RELAPSE 1
# 1739       NaN       NaN     NaN       NaN      NaN           NaN
# 975        NaN       NaN     NaN       NaN      NaN  MS RELAPSE 1
# 1397       NaN       NaN     NaN       NaN      NaN  MS RELAPSE 2
#
# [4487 rows x 44 columns]

# %% [markdown]
# Check how many different patients in the dataset

# %%
unique_count = clinical_events['USUBJID'].nunique()
print(f"Number of (unique) patients in this dataset: {unique_count}") #less than the total we have (2465)
# Out:
# Number of (unique) patients in this dataset: 1215

# %% [markdown]
# Check columns with missing values

# %%
missing_percentage_ce = (clinical_events.isnull().sum() / len(clinical_events)) * 100
missing_clinical_events = pd.DataFrame({'Column Name': missing_percentage_ce.index, 'Missing Percentage': missing_percentage_ce.values})
missing_clinical_events = missing_clinical_events.sort_values(by='Missing Percentage', ascending=False)
print(missing_clinical_events)
# Out:
#    Column Name  Missing Percentage
# 14      CESTAT          100.000000
# 37    CEEVLINT          100.000000
# 30     CESTDTC          100.000000
# 31     CEENDTC          100.000000
# 25     CETOXGR          100.000000
# 23     CESHOSP          100.000000
# 21      CEPATT          100.000000
# 35      CESTRF          100.000000
# 18       CELAT          100.000000
# 17       CELOC          100.000000
# 15    CEREASND          100.000000
# 29       CEDTC          100.000000
# 28       EPOCH          100.000000
# 11      CESCAT          100.000000
# 38    CEEVINTX          100.000000
# 39    CESTRTPT          100.000000
# 40     CESTTPT          100.000000
# 6       CESPID          100.000000
# 5      CEREFID          100.000000
# 4      CEGRPID          100.000000
# 41    CEENRTPT          100.000000
# 42     CEENTPT          100.000000
# 36      CEENRF           99.598841
# 22       CEOUT           87.162915
# 10       CECAT           85.892579
# 34      CEENDY           81.034099
# 24    CECONTRT           81.034099
# 20       CESER           78.493425
# 16    CEBODSYS           77.646534
# 43        MIDS           66.458658
# 33      CESTDY           56.139960
# 19       CESEV           55.449075
# 8     CEMODIFY           55.315355
# 9      CEDECOD           54.624471
# 13     CEOCCUR           45.375529
# 12     CEPRESP           45.375529
# 32        CEDY           44.684645
# 27       VISIT           39.915311
# 26    VISITNUM           39.915311
# 1       DOMAIN            0.000000
# 7       CETERM            0.000000
# 3        CESEQ            0.000000
# 2      USUBJID            0.000000
# 0      STUDYID            0.000000

# %% [markdown]
# Drop columns with more than 80% missing values and others, namely:
# - **STUDYID**: (irrelevant)
# - **DOMAIN**: (irrelevant)
# - **CEGRPID, CEREFID, CESPID, CESCAT, CESTAT, CEREASND, CELOC, CELAT, CEPATT, CETOXGR, EPOCH, CEDTC, CESTDTC, CEENDTC, CESTRF, CEEVLINT,CEEVINTX, CESTRTPT, CESTTPT, CEENRTPT, CEENTPT**: (all values missing and not mentioned in the dataset)
# - **VISITNUM**: Visit Number (kind of a code number for VISIT, they give the same info and missing value in same rows)
#
# Columns being dropped, but not sure if we *should keep*:
# - **CESHOSP**: Requires or Prolongs Hospitalization (all values missing but is mentioned in the dictionary)
# - **CECAT**: Category for Clinical Event (and 86% missing)
# - **CEOUT**: Outcome of Event (87% missing)
# - **CEENRF**: End Relative to Reference Period (99.6% missing)

# %%
# start by dropping columns with all missing
columns_to_drop = missing_clinical_events[missing_clinical_events['Missing Percentage'] > 85]['Column Name'].tolist()
additional_columns_to_drop = ['STUDYID', 'DOMAIN']  # Add your column names here
columns_to_drop.extend(additional_columns_to_drop)
clinical_events.drop(columns=columns_to_drop, inplace=True)
clinical_events
# Out:
#          USUBJID  CESEQ                        CETERM  \
# 432   MSOAC/0031      1                    MS RELAPSE
# 1334  MSOAC/0031      2                    MS RELAPSE
# 1022  MSOAC/0035      1  MS RELAPSE CONFIRMED BY EDSS
# 1368  MSOAC/0035      2  MS RELAPSE CONFIRMED BY EDSS
# 1819  MSOAC/0041      1            MS EXACERBATION #1
# ...          ...    ...                           ...
# 1959  MSOAC/9995      4        UNCONFIRMED MS RELAPSE
# 871   MSOAC/9998      1     Confirmed MS Exacerbation
# 1739  MSOAC/9998      2     Suspected MS Exacerbation
# 975   MSOAC/9999      1  MS RELAPSE CONFIRMED BY EDSS
# 1397  MSOAC/9999      2  MS RELAPSE CONFIRMED BY EDSS
#
#                            CEMODIFY                     CEDECOD CEPRESP  \
# 432   Neurologist Confirmed Relapse  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1334  Neurologist Confirmed Relapse  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1022         EDSS Confirmed Relapse  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1368         EDSS Confirmed Relapse  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1819  MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# ...                             ...                         ...     ...
# 1959              Suspected Relapse          RELAPSE-LIKE EVENT     NaN
# 871                             NaN  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1739                            NaN          RELAPSE-LIKE EVENT     NaN
# 975          EDSS Confirmed Relapse  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1397         EDSS Confirmed Relapse  MULTIPLE SCLEROSIS RELAPSE     NaN
#
#      CEOCCUR                  CEBODSYS     CESEV CESER CECONTRT  VISITNUM  \
# 432      NaN  Nervous system disorders      MILD     N        Y       NaN
# 1334     NaN  Nervous system disorders      MILD     N        Y       NaN
# 1022     NaN                       NaN  MODERATE   NaN      NaN       NaN
# 1368     NaN                       NaN  MODERATE   NaN      NaN       NaN
# 1819     NaN  Nervous system disorders      MILD     N      NaN       NaN
# ...      ...                       ...       ...   ...      ...       ...
# 1959     NaN                       NaN      MILD   NaN      NaN       NaN
# 871      NaN  Nervous system disorders       NaN   NaN        Y       3.0
# 1739     NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 975      NaN                       NaN      MILD   NaN      NaN       NaN
# 1397     NaN                       NaN      MILD   NaN      NaN       NaN
#
#             VISIT  CEDY  CESTDY  CEENDY          MIDS
# 432           NaN   NaN   268.0   279.0  MS RELAPSE 1
# 1334          NaN   NaN   814.0     NaN  MS RELAPSE 2
# 1022          NaN   NaN   144.0     NaN  MS RELAPSE 1
# 1368          NaN   NaN   221.0     NaN  MS RELAPSE 2
# 1819          NaN   NaN   179.0     NaN           NaN
# ...           ...   ...     ...     ...           ...
# 1959          NaN   NaN   682.0     NaN           NaN
# 871       MONTH 3  85.0    79.0     NaN  MS RELAPSE 1
# 1739  UNSCHEDULED  95.0     NaN     NaN           NaN
# 975           NaN   NaN    69.0     NaN  MS RELAPSE 1
# 1397          NaN   NaN   359.0     NaN  MS RELAPSE 2
#
# [4487 rows x 17 columns]

# %% [markdown]
# - descriptive analysis of continuous variables

# %%
continuous_columns = ['CEDY','CESTDY','CEENDY']

descriptive_continuous = {
    'Count': clinical_events[continuous_columns].count(), #cases that are not missing
    'Missing Cases': clinical_events[continuous_columns].isna().sum(),
    'Mean': clinical_events[continuous_columns].mean(),
    'Standard Deviation': clinical_events[continuous_columns].std()
}

cont_clinical_events = pd.DataFrame(descriptive_continuous)

print(cont_clinical_events)
# Out:
#         Count  Missing Cases        Mean  Standard Deviation
# CEDY     2482           2005  383.682917          219.006862
# CESTDY   1968           2519  385.452236          298.653233
# CEENDY    851           3636  331.262045          221.707530

# %%
CEDY = clinical_events['CEDY'].dropna()

plt.figure(figsize=(8, 6))
sns.histplot(CEDY, kde=True, color='red', bins=30)
plt.xlabel('CEDY')
plt.ylabel('Density')
plt.title('Histogram with Density Line for CEDY')
plt.show() # more or less normaly distributed

# %%
CESTDY = clinical_events['CESTDY'].dropna()

plt.figure(figsize=(8, 6))
sns.histplot(CESTDY, kde=True, color='red', bins=30)
plt.xlabel('CESTDY')
plt.ylabel('Density')
plt.title('Histogram with Density Line for CESTDY')
plt.show()

# %% [markdown]
# - descriptive analysis of categorical variables

# %%
ceterm_counts_clinical_events = clinical_events['CETERM'].value_counts().reset_index()
ceterm_counts_clinical_events.columns = ['CETERM', 'Count']
print(ceterm_counts_clinical_events.head(55))
# Out:
#                                      CETERM  Count
# 0         POSSIBLE RELAPSE SINCE LAST VISIT   2451
# 1              MS RELAPSE CONFIRMED BY EDSS    762
# 2                                MS RELAPSE    573
# 3                    UNCONFIRMED MS RELAPSE    271
# 4                           MS EXACERBATION     30
# 5             RELAPSE OF MULTIPLE SCLEROSIS     23
# 6                                MS-RELAPSE     21
# 7                             RELAPSE OF MS     20
# 8                 Confirmed MS Exacerbation     19
# 9                                   RELAPSE     18
# 10                                MS RELAPS     14
# 11                             MS - RELAPSE     14
# 12                            MS RELAPSE #1     12
# 13                Suspected MS Exacerbation     12
# 14               MULTIPLE SCLEROSIS RELAPSE     10
# 15                             M.S. RELAPSE      8
# 16          MS RELAPSE NON-PROTOCOL DEFINED      7
# 17           MS RELAPSE DEFINED BY PROTOCOL      6
# 18         MS RELAPSE: NON-PROTOCOL DEFINED      6
# 19          NON PROTOCOL DEFINED MS RELAPSE      6
# 20                        Suspected Relapse      6
# 21                        M.S. EXACERBATION      5
# 22                               RELAPSE MS      5
# 23          MS RELAPSE NON PROTOCOL DEFINED      5
# 24              PROTOCOL DEFINED MS RELAPSE      4
# 25        HOSPITALIZATION DUE TO MS RELAPSE      4
# 26                                MS ATTACK      4
# 27                            MS RELAPSE #2      4
# 28    HOSPITALISATION BECAUSE OF MS RELAPSE      3
# 29             RELAPSE - MULTIPLE SCLEROSIS      3
# 30                              MS- RELAPSE      3
# 31              OPTIC NEURITIS (MS RELAPSE)      2
# 32                       SENSORY MS RELAPSE      2
# 33                          M.S. RELAPSE #2      2
# 34                               RELAPSE #2      2
# 35                               RELAPSE #1      2
# 36              MULTIPLE SCLEROSIS, RELAPSE      2
# 37        MS RELAPSE (NON-PROTOCOL DEFINED)      2
# 38                             RELAPS OF MS      2
# 39                      PROTOCOL MS RELAPSE      2
# 40        MS RELAPSE (NON PROTOCOL DEFINED)      2
# 41                           MS RELAPSE # 1      2
# 42         MS-RELAPSE, NON-PROTOCOL-DEFINED      1
# 43             MS EXACERBATION OF SYMPTOMPS      1
# 44                 WORSENING OF MS SYMPTOMS      1
# 45           ACUTE ATAXIA OF GAIT (RELAPSE)      1
# 46                         M.S. RELAPSE # 1      1
# 47                MS RELAPSE R LEG NUMBNESS      1
# 48       RESIDUAL SYMPTOMS FROM FLARE OF MS      1
# 49       ADMISSION TO REHAB HOSPITAL FOR MS      1
# 50  WEAKNESS OF BOTH LEGS DUE TO MS-RELAPSE      1
# 51                             MS RELAPSE I      1
# 52         MS RELAPSE: NOT PROTOCOL DEFINED      1
# 53  PARAPARESIS OF LOWER LIMBS - MS RELAPSE      1
# 54                         MS PSEUDORELAPSE      1

# %%
import Levenshtein

# Function to calculate Levenshtein distance
def levenshtein_distance(str1, str2):
    return Levenshtein.distance(str1, str2)

# Function to group CETERM values based on edit distance
def group_by_edit_distance(df, column, threshold):
    grouped_categories = {}

    def group_category(category):
        for group_name, group_members in grouped_categories.items():
            for member in group_members:
                if levenshtein_distance(category, member) <= threshold:
                    return group_name
        return category

    original_categories = df[column].tolist()

    for index, row in df.iterrows():
        category = row[column]
        group_name = group_category(category)
        
        if group_name not in grouped_categories:
            grouped_categories[group_name] = {category}
        else:
            grouped_categories[group_name].add(category)

    return original_categories, grouped_categories

# Function to print original and grouped categories
def print_original_and_grouped(original_categories, grouped_categories):
    print("Original Categories:")
    print(original_categories)

    print("\nGrouped Categories:")
    num_groups = 0
    for group_name, distinct_values in grouped_categories.items():
        num_groups += 1
        print(f"Group: {group_name}, Number of Distinct Values: {len(distinct_values)}") #, Distinct Values: {distinct_values}

    print("\nNumber of Groups Created:", num_groups)

# Example usage
#data = {'CETERM': ['headache', 'head ache', 'back pain', 'pain in the back', 'fever', 'high fever']}
#clinical_events = pd.DataFrame(data)

threshold = 12
original_categories, grouped_categories = group_by_edit_distance(clinical_events, 'CETERM', threshold)
print_original_and_grouped(original_categories, grouped_categories)
# Out:
# Original Categories:
# ['MS RELAPSE', 'MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS EXACERBATION #1', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'UNCONFIRMED MS RELAPSE', 'UNCONFIRMED MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE', 'MS RELAPSE', 'MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'MS EXACERBATION', 'MS RELAPSE', 'MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'RELAPSE MS', 'MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'MS-RELAPSE - DIPLOPIA', 'MS-RELAPSE', 'RELAPSE', 'MS RELAPS', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE', 'Suspected Relapse', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'MS RELAPSE', 'UNCONFIRMED MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'UNCONFIRMED MS RELAPSE', 'UNCONFIRMED MS RELAPSE', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'WORSENING OF MS PREEXIST SXS MS RELAPSE', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'MS RELAPSE CONFIRMED BY EDSS', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RELAPSE SINCE LAST VISIT', 'POSSIBLE RE ...
#
# Grouped Categories:
# Group: MS RELAPSE, Number of Distinct Values: 63
# Group: MS RELAPSE CONFIRMED BY EDSS, Number of Distinct Values: 1
# Group: MS EXACERBATION #1, Number of Distinct Values: 1
# Group: POSSIBLE RELAPSE SINCE LAST VISIT, Number of Distinct Values: 1
# Group: Suspected Relapse, Number of Distinct Values: 1
# Group: WORSENING OF MS PREEXIST SXS MS RELAPSE, Number of Distinct Values: 3
# Group: RELAPSE OF MULTIPLE SCLEROSIS, Number of Distinct Values: 6
# Group: MS RELAPSE (NON PROTOCOL DEFINED), Number of Distinct Values: 11
# Group: WORSENING MS SYMPTOMS, Number of Distinct Values: 4
# Group: HOSPITALIZATION DUE TO MS RELAPSE, Number of Distinct Values: 8
# Group: MS RELAPSE (PARESIS OF RIGHT LEG), Number of Distinct Values: 3
# Group: MS RELAPSE (SPASTICITY OF LEGS (SIGNIFICANT PROGRESSION)), Number of Distinct Values: 1
# Group: MS RELAPSE - HOSPITALISATION, Number of Distinct Values: 7
# Group: MULTIPLE SCLEROSIS RELAPSE, Number of Distinct Values: 3
# Group: MS-RELAPSE WITH FATIGUE INCREASED, Number of Distinct Values: 1
# Group: INCREASED BILATERAL LEG WEAKNESS SECONDARY TO MS RELAPSE, Number of Distinct Values: 1
# Group: INCREASED EMOTIONAL STRESS SECONDARY TO MS RELAPSE, Number of Distinct Values: 1
# Group: MS RELAPSE (SENSORY DISTURBANCES), Number of Distinct Values: 2
# Group: Confirmed MS Exacerbation, Number of Distinct Values: 2
# Group: TRANSISTENT WORSENING OF MS SYMPTOMS (NOT MS RELAPSE), Number of Distinct Values: 2
# Group: MS RELAPSE DEFINED BY PROTOCOL, Number of Distinct Values: 1
# Group: HOSPITALISATION BECAUSE OF MS RELAPSE DEFINED BY PROTOCOL, Number of Distinct Values: 1
# Group: UTHOFF PHENOMENON, Number of Distinct Values: 1
# Group: NUMBNESS FEET (MS RELAPSE), Number of Distinct Values: 3
# Group: (MS RELAPSE) FATIGUE, REDUCED WALKING DISTANCE, DIFFICULTY IN WALKING, WEAKNESS IN THE RIGHT LEG, Number of Distinct Values: 1
# Group: MS RELAPSE NON PROTOCOL DEFINED (WEAKNESS AND NUMBNESS OF BOTH UPPER AND LOWER LIMBS), Number of Distinct Values: 1
# Group: MS RELAPSE SEVERE PAIN AND WEAKNESS OF LOWER LIMBS, Number of Distinct Values: 1
# Group: MS RELAPSE WEAKNESS OF LOWER LIMBS, Number of Distinct Values: 1
# Group: RELAPSE FATIGUE, INCREASED SPASTICITY, DIFFICULTY TO WALK, Number of Distinct Values: 1
# Group: MILD MS ATTACK (RELAPSE), Number of Distinct Values: 1
# Group: MS RELAPSE #1 (LEFT FOOT DROP, INCREASED FATIGUE, INCREASED LEFT SIDE WEAK ON EXAM), Number of Distinct Values: 1
# Group: MS RELAPSE #2 (CONFIRMED AS RELAPSE ON [REDACTED]), Number of Distinct Values: 1
# Group: INFECTION ASSOCIATED MS PROGRESSION, Number of Distinct Values: 1
# Group: PSEUDO RELAPSE DUE TO UPPER RESPIRATORY TRACT INFECTION, Number of Distinct Values: 1
# Group: DECREASE IN WALKING DISTANCE/RELAPSE OF MULTIPLE SCLEROSIS, Number of Distinct Values: 1
# Group: INCREASED LEG TWITCHING WITH R GREATER THAN L RELATED TO MS RELAPSE, Number of Distinct Values: 1
# Group: MS RELAPSE/OPTIC NEURITIS, Number of Distinct Values: 1
# Group: MS RELAPSE - NUMBNESS AND WEAKNESS LOWER LIMBS, Number of Distinct Values: 1
# Group: DIZZINESS RELATED TO POSSIBLE MS RELAPSE, Number of Distinct Values: 2
# Group: GENERAL PHYSICAL HEALTH DETERIORATION (MS PROGRESSION), Number of Distinct Values: 1
# Group: HOSPITALIZATION FOR RELAPSE TREATMENT, Number of Distinct Values: 1
# Group: MS RELAPSE (NUMBNESS OF BOTH ARMS, VISUAL WORSENING, WALKING ABILITY WORSED), Number of Distinct Values: 1
# Group: MS RELAPSE ( (R) SIDED NUMBNESS), Number of Distinct Values: 1
# Group: MS RELAPSE NO. 4 (PRIOR TO VISIT 14), Number of Distinct Values: 1
# Group: MS RELAPSE (REPORTED WEAKNESS IN LEGS), Number of Distinct Values: 2
# Group: MS RELAPSE SECONDARY TO ACUTE INFECTION (INFLUENZA PNEUMONIA), Number of Distinct Values: 1
# Group: MS RELAPSE RELAPSE 2 NUMBNESS IN RIGHT SIDE OF BODY, Number of Distinct Values: 1
# Group: MS RELAPSE RELAPSE 3 - WEAKNESS OF BOTH LEGS -URINE HAS FOUL ODOR, Number of Distinct Values: 1
# Group: RELAPSE OF MULTIPLE SCLEROSIS - NUMBNESS L) SIDE BODY, Number of Distinct Values: 1
# Group: MS RELAPSE: WORSENING NUMBNESS L) BODY SIDE, Number of Distinct Values: 1
# Group: PARAESTHESIA R) SIDE OF FACE (MS RELAPSE), Number of Distinct Values: 1
# Group: RELAPSE OF MULTIPLE SCLEROSIS - INCREASING WEAKNESS, Number of Distinct Values: 1
# Group: PARAPARESIS OF LOWER LIMBS - MS RELAPSE, Number of Distinct Values: 1
# Group: NUMBNESS, BURNING AND SOME INCREASED WEAKNESS LEFT FOOT=RELAPSE, Number of Distinct Values: 1
# Group: WEAKNESS OF BOTH LEGS DUE TO MS-RELAPSE, Number of Distinct Values: 1
# Group: OPTIC NEURITIS (MS RELAPSE), Number of Distinct Values: 1
# Group: MS DISEASE PROGRESSION, Number of Distinct Values: 1
# Group: MS RELAPSE (TINGLING IN BOTH HANDS), Number of Distinct Values: 1
# Group: LEG WEAKNESS (MS EXACERBATION), Number of Distinct Values: 1
# Group: MS RELAPSE WITH DECREASED STRENGTH LEGS, Number of Distinct Values: 1
# Group: RELAPSE OF MS WITH MASSIVE WORSENING OF, Number of Distinct Values: 1
# Group: M.S. RELAPSE WORSENING OF RIGHT LEG WEAKNESS, Number of Distinct Values: 1
# Group: RELAPSE: INCREASED WEAKNESS LEFT LEG, Number of Distinct Values: 1
# Group: MS EXACERBATION WITH WORSENING OF GAIT, Number of Distinct Values: 1
# Group: MS RELAPSE (SPONTANEOUS NYSTAGMUS), Number of Distinct Values: 1
# Group: "BURNING PAIN IN LEFT LEG" = MS SENSORY RELAPSE, Number of Distinct Values: 1
# Group: PROGRESSIVE MS SYMPTOM (IMPAIRED WALKING, PARESTHESIA, DISTURBED BALANCE), Number of Distinct Values: 1
# Group: RELAPSE WITH NEURALGIA OF TRIGEMINAL, Number of Distinct Values: 1
# Group: ACUTE ATAXIA OF GAIT (RELAPSE), Number of Distinct Values: 1
# Group: RESIDUAL SYMPTOMS FROM FLARE OF MS, Number of Distinct Values: 1
# Group: ADMISSION TO REHAB HOSPITAL FOR MS, Number of Distinct Values: 1
# Group: MS RELAPSE-PROGRESSIVE LEG WEAKNESS, Number of Distinct Values: 1
#
# Number of Groups Created: 72

# %%
# Pie chart - dropped NA for now
categories = clinical_events['CETERM'].dropna().unique()
category_counts = clinical_events['CETERM'].dropna().value_counts()

plt.pie(category_counts, labels=categories, autopct='%1.1f%%', startangle=90)
#plt.legend(labels=categories, loc='lower right', bbox_to_anchor=(1.2, 1))
plt.axis('equal')
plt.show() #do something with this one

# %%
#when CETERM is 'POSSIBLE RELAPSE SINCE LAST VISIT', there is no information for CEMODIFY - so we "merge" these columns
cemodify_counts_clinical_events = clinical_events['CEMODIFY'].value_counts().reset_index()
cemodify_counts_clinical_events.columns = ['CEMODIFY', 'Count']
print(cemodify_counts_clinical_events) # DROP!!! -- or this one might be more important than TERM
# Out:
#                              CEMODIFY  Count
# 0              EDSS Confirmed Relapse    762
# 1                   Suspected Relapse    470
# 2       Neurologist Confirmed Relapse    459
# 3              INEC Confirmed Relapse    181
# 4                   Confirmed Relapse     84
# 5        Non-Protocol Defined Relapse     24
# 6                  Multiple Sclerosis     14
# 7       MULTIPLE SCLEROSIS AGGRAVATED      7
# 8   PROGRESSION OF MULTIPLE SCLEROSIS      2
# 9                  MULTIPLE SCLEROSIS      1
# 10                   MS-LIKE SYNDROME      1

# %%
filtered_ce = clinical_events[clinical_events['CEMODIFY'].isin(['Multiple Sclerosis','MULTIPLE SCLEROSIS AGGRAVATED','PROGRESSION OF MULTIPLE SCLEROSIS','MULTIPLE SCLEROSIS','MS-LIKE SYNDROME'])]
filtered_ce
# Out:
#          USUBJID  CESEQ                                             CETERM  \
# 1819  MSOAC/0041      1                                 MS EXACERBATION #1
# 1730  MSOAC/0539      1                              WORSENING MS SYMPTOMS
# 48    MSOAC/0649      1                                       MS WORSENING
# 319   MSOAC/1420      1  TRANSISTENT WORSENING OF MS SYMPTOMS (NOT MS R...
# 362   MSOAC/1420      2  TRANSIENT WORSENING OF MS SYMPTOMS (NOT MS REL...
# 2009  MSOAC/1816      1                                  UTHOFF PHENOMENON
# 125   MSOAC/2918      1                           WORSENING OF MS-SYMPTOMS
# 2012  MSOAC/3151      1                        PROGRESSION OFF MS-SYMPTOMS
# 212   MSOAC/3246      1                        DETERIORATON OF MS SYMPTOMS
# 736   MSOAC/3581      2                INFECTION ASSOCIATED MS PROGRESSION
# 1732  MSOAC/3663      2  PSEUDO RELAPSE DUE TO UPPER RESPIRATORY TRACT ...
# 413   MSOAC/4363      1                                   DETERIORATION MS
# 559   MSOAC/4481      3                                     PSEUDO-RELAPSE
# 1721  MSOAC/4651      1  GENERAL PHYSICAL HEALTH DETERIORATION (MS PROG...
# 2010  MSOAC/5737      1                       DETERIORATION OF MS SYMPTOMS
# 671   MSOAC/6907      4                                   MS PSEUDORELAPSE
# 577   MSOAC/7194      1                       MS EXACERBATION OF SYMPTOMPS
# 1725  MSOAC/7647      1                             MS DISEASE PROGRESSION
# 393   MSOAC/8058      1                                    WORSENING OF MS
# 635   MSOAC/8189      2                DETERIORATION OF MULTIPLE SCLEROSIS
# 1723  MSOAC/8342      1                                    MS IS WORSENING
# 2014  MSOAC/9338      1  PROGRESSIVE MS SYMPTOM (IMPAIRED WALKING, PARE...
# 2011  MSOAC/9497      1                           WORSENING OF MS SYMPTOMS
# 1722  MSOAC/9637      1                 ADMISSION TO REHAB HOSPITAL FOR MS
# 761   MSOAC/9921      1                                    MS EXACERBATION
#
#                                CEMODIFY             CEDECOD CEPRESP CEOCCUR  \
# 1819      MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
# 1730                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 48                   MULTIPLE SCLEROSIS  Multiple sclerosis     NaN     NaN
# 319                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 362                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 2009                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 125       MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
# 2012  PROGRESSION OF MULTIPLE SCLEROSIS  MULTIPLE SCLEROSIS     NaN     NaN
# 212                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 736                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 1732                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 413                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 559                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 1721                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 2010      MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
# 671                    MS-LIKE SYNDROME  MULTIPLE SCLEROSIS     NaN     NaN
# 577       MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
# 1725                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 393                  Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 635       MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
# 1723                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 2014  PROGRESSION OF MULTIPLE SCLEROSIS  MULTIPLE SCLEROSIS     NaN     NaN
# 2011      MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
# 1722                 Multiple Sclerosis  MULTIPLE SCLEROSIS     NaN     NaN
# 761       MULTIPLE SCLEROSIS AGGRAVATED  MULTIPLE SCLEROSIS     NaN     NaN
#
#                       CEBODSYS     CESEV CESER CECONTRT  VISITNUM VISIT  CEDY  \
# 1819  Nervous system disorders      MILD     N      NaN       NaN   NaN   NaN
# 1730  Nervous system disorders      MILD     N        Y       NaN   NaN   NaN
# 48    Nervous system disorders      MILD     N      NaN       NaN   NaN   NaN
# 319   Nervous system disorders      MILD     N        N       NaN   NaN   NaN
# 362   Nervous system disorders      MILD     N        N       NaN   NaN   NaN
# 2009  Nervous system disorders      MILD   NaN      NaN       NaN   NaN   NaN
# 125   Nervous system disorders      MILD     N      NaN       NaN   NaN   NaN
# 2012  Nervous system disorders  MODERATE     N      NaN       NaN   NaN   NaN
# 212   Nervous system disorders      MILD     N        N       NaN   NaN   NaN
# 736   Nervous system disorders      MILD     Y        N       NaN   NaN   NaN
# 1732  Nervous system disorders  MODERATE     N        Y       NaN   NaN   NaN
# 413   Nervous system disorders  MODERATE     N        N       NaN   NaN   NaN
# 559   Nervous system disorders    SEVERE     Y        N       NaN   NaN   NaN
# 1721  Nervous system disorders  MODERATE     N        N       NaN   NaN   NaN
# 2010  Nervous system disorders  MODERATE     N      NaN       NaN   NaN   NaN
# 671   Nervous system disorders    SEVERE     Y      NaN       NaN   NaN   NaN
# 577   Nervous system disorders  MODERATE     N      NaN       NaN   NaN   NaN
# 1725  Nervous system disorders    SEVERE     N        N       NaN   NaN   NaN
# 393   Nervous system disorders    SEVERE     Y        Y       NaN   NaN   NaN
# 635   Nervous system disorders  MODERATE     Y      NaN       NaN   NaN   NaN
# 1723  Nervous system disorders  MODERATE     N        N       NaN   NaN   NaN
# 2014  Nervous system disorders  MODERATE     N      NaN       NaN   NaN   NaN
# 2011  Nervous system disorders  MODERATE     N      NaN       NaN   NaN   NaN
# 1722  Nervous system disorders  MODERATE     Y        N       NaN   NaN   NaN
# 761   Nervous system disorders  MODERATE     Y      NaN       NaN   NaN   NaN
#
#       CESTDY  CEENDY MIDS
# 1819   179.0     NaN  NaN
# 1730   398.0     NaN  NaN
# 48      47.0    56.0  NaN
# 319    211.0   213.0  NaN
# 362    239.0   246.0  NaN
# 2009     NaN     NaN  NaN
# 125     92.0    96.0  NaN
# 2012     NaN     NaN  NaN
# 212    110.0   144.0  NaN
# 736    628.0   630.0  NaN
# 1732   633.0     NaN  NaN
# 413    144.0   267.0  NaN
# 559    379.0   382.0  NaN
# 1721   335.0     NaN  NaN
# 2010     NaN     NaN  NaN
# 671    538.0   543.0  NaN
# 577    398.0   409.0  NaN
# 1725     NaN     NaN  NaN
# 393      NaN   254.0  NaN
# 635    489.0   494.0  NaN
# 1723   518.0     NaN  NaN
# 2014     NaN     NaN  NaN
# 2011     NaN     NaN  NaN
# 1722   344.0     NaN  NaN
# 761    661.0   665.0  NaN

# %%
relation = clinical_events.loc[clinical_events['CEMODIFY'].isnull(), 'CETERM'].unique()
relation
# Out:
# array(['POSSIBLE RELAPSE SINCE LAST VISIT', 'Confirmed MS Exacerbation',
#        'Suspected MS Exacerbation'], dtype=object)

# %%
#when CETERM is 'POSSIBLE RELAPSE SINCE LAST VISIT', there is no information for CEMODIFY - so we "merge" these columns
clinical_events['CEMODIFY'].fillna(clinical_events['CETERM'], inplace=True)
cemodify_counts_clinical_events = clinical_events['CEMODIFY'].value_counts().reset_index()
cemodify_counts_clinical_events.columns = ['CEMODIFY', 'Count']
print(cemodify_counts_clinical_events) # DROP!!! -- or this one might be more important than TERM
# Out:
#                              CEMODIFY  Count
# 0   POSSIBLE RELAPSE SINCE LAST VISIT   2451
# 1              EDSS Confirmed Relapse    762
# 2                   Suspected Relapse    470
# 3       Neurologist Confirmed Relapse    459
# 4              INEC Confirmed Relapse    181
# 5                   Confirmed Relapse     84
# 6        Non-Protocol Defined Relapse     24
# 7           Confirmed MS Exacerbation     19
# 8                  Multiple Sclerosis     14
# 9           Suspected MS Exacerbation     12
# 10      MULTIPLE SCLEROSIS AGGRAVATED      7
# 11  PROGRESSION OF MULTIPLE SCLEROSIS      2
# 12                 MULTIPLE SCLEROSIS      1
# 13                   MS-LIKE SYNDROME      1

# %%
ms_entries = ['Multiple Sclerosis','MULTIPLE SCLEROSIS', 'MULTIPLE SCLEROSIS AGGRAVATED', 'PROGRESSION OF MULTIPLE SCLEROSIS', 'MS-LIKE SYNDROME','Confirmed MS Exacerbation','Suspected MS Exacerbation']

# Filter rows where 'CEMODIFY' is in the list of Multiple Sclerosis entries
result = clinical_events[clinical_events['CEMODIFY'].isin(ms_entries)]
result
# Out:
#          USUBJID  CESEQ                                             CETERM  \
# 1819  MSOAC/0041      1                                 MS EXACERBATION #1
# 1730  MSOAC/0539      1                              WORSENING MS SYMPTOMS
# 48    MSOAC/0649      1                                       MS WORSENING
# 875   MSOAC/1137      1                          Confirmed MS Exacerbation
# 4482  MSOAC/1248      1                          Suspected MS Exacerbation
# 881   MSOAC/1248      2                          Confirmed MS Exacerbation
# 1331  MSOAC/1248      3                          Confirmed MS Exacerbation
# 319   MSOAC/1420      1  TRANSISTENT WORSENING OF MS SYMPTOMS (NOT MS R...
# 362   MSOAC/1420      2  TRANSIENT WORSENING OF MS SYMPTOMS (NOT MS REL...
# 2009  MSOAC/1816      1                                  UTHOFF PHENOMENON
# 898   MSOAC/2698      1                          Confirmed MS Exacerbation
# 872   MSOAC/2719      1                          Confirmed MS Exacerbation
# 4484  MSOAC/2800      1                          Suspected MS Exacerbation
# 125   MSOAC/2918      1                           WORSENING OF MS-SYMPTOMS
# 4483  MSOAC/2966      1                          Suspected MS Exacerbation
# 865   MSOAC/3013      1                          Confirmed MS Exacerbation
# 1336  MSOAC/3013      2                          Confirmed MS Exacerbation
# 4486  MSOAC/3018      1                          Suspected MS Exacerbation
# 1737  MSOAC/3133      1                          Suspected MS Exacerbation
# 2012  MSOAC/3151      1                        PROGRESSION OFF MS-SYMPTOMS
# 212   MSOAC/3246      1                        DETERIORATON OF MS SYMPTOMS
# 736   MSOAC/3581      2                INFECTION ASSOCIATED MS PROGRESSION
# 1732  MSOAC/3663      2  PSEUDO RELAPSE DUE TO UPPER RESPIRATORY TRACT ...
# 1098  MSOAC/4095      1                          Confirmed MS Exacerbation
# 413   MSOAC/4363      1                                   DETERIORATION MS
# 559   MSOAC/4481      3                                     PSEUDO-RELAPSE
# 1721  MSOAC/4651      1  GENERAL PHYSICAL HEALTH DETERIORATION (MS PROG...
# 1736  MSOAC/4760      1                          Suspected MS Exacerbation
# 4485  MSOAC/4845      1                          Suspected MS Exacerbation
# 1740  MSOAC/5113      1                          Suspected MS Exacerbation
# 893   MSOAC/5156      1                          Confirmed MS Exacerbation
# 2077  MSOAC/5558      1                          Suspected MS Exacerbation
# 890   MSOAC/5558      2                          Confirmed MS Exacerbation
# 2010  MSOAC/5737      1                       DETERIORATION OF MS SYMPTOMS
# 887   MSOAC/5971      1                          Confirmed MS Exacerbation
# 888   MSOAC/6260      1                          Confirmed MS Exacerbation
# 1738  MSOAC/6788      1                          Suspected MS Exacerbation
# 671   MSOAC/6907      4                                   MS PSEUDORELAPSE
# 577   MSOAC/7194      1                       MS EXACERBATION OF SYMPTOMPS
# 895   MSOAC/7271      1                          Confirmed MS Exacerbation
# 1725  MSOAC/7647      1                             MS DISEASE PROGRESSION
# 393   MSOAC/8058      1                                    WORSENING OF MS
# 635   MSOAC/8189      2                DETERIORATION OF MULTIPLE SCLEROSIS
# 1723  MSOAC/8342      1                                    MS IS WORSENING
# 886   MSOAC/8587      1                          Confirmed MS Exacerbation
# 2467  MSOAC/8602      1                          Suspected MS Exacerbation
# 880   MSOAC/8602      2                          Confirmed MS Exacerbation
# 892   MSOAC/8818      1                          Confirmed MS Exacerbation
# 2014  MSOAC/9338      1  PROGRESSIVE MS SYMPTOM (IMPAIRED WALKING, PARE...
# 883   MSOAC/9474      1                          Confirmed MS Exacerbation
# 2011  MSOAC/9497      1                           WORSENING OF MS SYMPTOMS
# 1071  MSOAC/9595      1                          Confirmed MS Exacerbation
# 1722  MSOAC/9637      1                 ADMISSION TO REHAB HOSPITAL FOR MS
# 761   MSOAC/9921      1                                    MS EXACERBATION
# 871   MSOAC/9998      1                          Confirmed MS Exacerbation
# 1739  MSOAC/9998      2                          Suspected MS Exacerbation
#
#                                CEMODIFY                     CEDECOD CEPRESP  \
# 1819      MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 1730                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 48                   MULTIPLE SCLEROSIS          Multiple sclerosis     NaN
# 875           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 4482          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 881           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1331          Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 319                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 362                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 2009                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 898           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 872           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 4484          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 125       MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 4483          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 865           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1336          Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 4486          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 1737          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 2012  PROGRESSION OF MULTIPLE SCLEROSIS          MULTIPLE SCLEROSIS     NaN
# 212                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 736                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 1732                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 1098          Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 413                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 559                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 1721                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 1736          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 4485          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 1740          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 893           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 2077          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 890           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 2010      MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 887           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 888           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1738          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 671                    MS-LIKE SYNDROME          MULTIPLE SCLEROSIS     NaN
# 577       MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 895           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1725                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 393                  Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 635       MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 1723                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 886           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 2467          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
# 880           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 892           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 2014  PROGRESSION OF MULTIPLE SCLEROSIS          MULTIPLE SCLEROSIS     NaN
# 883           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 2011      MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 1071          Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1722                 Multiple Sclerosis          MULTIPLE SCLEROSIS     NaN
# 761       MULTIPLE SCLEROSIS AGGRAVATED          MULTIPLE SCLEROSIS     NaN
# 871           Confirmed MS Exacerbation  MULTIPLE SCLEROSIS RELAPSE     NaN
# 1739          Suspected MS Exacerbation          RELAPSE-LIKE EVENT     NaN
#
#      CEOCCUR                  CEBODSYS     CESEV CESER CECONTRT  VISITNUM  \
# 1819     NaN  Nervous system disorders      MILD     N      NaN       NaN
# 1730     NaN  Nervous system disorders      MILD     N        Y       NaN
# 48       NaN  Nervous system disorders      MILD     N      NaN       NaN
# 875      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 4482     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 881      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 1331     NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 319      NaN  Nervous system disorders      MILD     N        N       NaN
# 362      NaN  Nervous system disorders      MILD     N        N       NaN
# 2009     NaN  Nervous system disorders      MILD   NaN      NaN       NaN
# 898      NaN  Nervous system disorders       NaN   NaN        Y      24.0
# 872      NaN  Nervous system disorders       NaN   NaN        Y       6.0
# 4484     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 125      NaN  Nervous system disorders      MILD     N      NaN       NaN
# 4483     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 865      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 1336     NaN  Nervous system disorders       NaN   NaN        Y      27.0
# 4486     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 1737     NaN  Nervous system disorders       NaN   NaN        Y      24.0
# 2012     NaN  Nervous system disorders  MODERATE     N      NaN       NaN
# 212      NaN  Nervous system disorders      MILD     N        N       NaN
# 736      NaN  Nervous system disorders      MILD     Y        N       NaN
# 1732     NaN  Nervous system disorders  MODERATE     N        Y       NaN
# 1098     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 413      NaN  Nervous system disorders  MODERATE     N        N       NaN
# 559      NaN  Nervous system disorders    SEVERE     Y        N       NaN
# 1721     NaN  Nervous system disorders  MODERATE     N        N       NaN
# 1736     NaN  Nervous system disorders       NaN   NaN        Y      18.0
# 4485     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 1740     NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 893      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 2077     NaN  Nervous system disorders       NaN   NaN      NaN       3.0
# 890      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 2010     NaN  Nervous system disorders  MODERATE     N      NaN       NaN
# 887      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 888      NaN  Nervous system disorders       NaN   NaN        Y      15.0
# 1738     NaN  Nervous system disorders       NaN   NaN        Y      27.0
# 671      NaN  Nervous system disorders    SEVERE     Y      NaN       NaN
# 577      NaN  Nervous system disorders  MODERATE     N      NaN       NaN
# 895      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 1725     NaN  Nervous system disorders    SEVERE     N        N       NaN
# 393      NaN  Nervous system disorders    SEVERE     Y        Y       NaN
# 635      NaN  Nervous system disorders  MODERATE     Y      NaN       NaN
# 1723     NaN  Nervous system disorders  MODERATE     N        N       NaN
# 886      NaN  Nervous system disorders       NaN   NaN        Y     998.0
# 2467     NaN  Nervous system disorders       NaN   NaN      NaN       6.0
# 880      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 892      NaN  Nervous system disorders       NaN   NaN        Y     999.0
# 2014     NaN  Nervous system disorders  MODERATE     N      NaN       NaN
# 883      NaN  Nervous system disorders       NaN   NaN        Y      12.0
# 2011     NaN  Nervous system disorders  MODERATE     N      NaN       NaN
# 1071     NaN  Nervous system disorders       NaN   NaN      NaN     999.0
# 1722     NaN  Nervous system disorders  MODERATE     Y        N       NaN
# 761      NaN  Nervous system disorders  MODERATE     Y      NaN       NaN
# 871      NaN  Nervous system disorders       NaN   NaN        Y       3.0
# 1739     NaN  Nervous system disorders       NaN   NaN        Y     999.0
#
#                     VISIT    CEDY  CESTDY  CEENDY          MIDS
# 1819                  NaN     NaN   179.0     NaN           NaN
# 1730                  NaN     NaN   398.0     NaN           NaN
# 48                    NaN     NaN    47.0    56.0           NaN
# 875           UNSCHEDULED   159.0   146.0     NaN  MS RELAPSE 1
# 4482          UNSCHEDULED   281.0     NaN     NaN           NaN
# 881           UNSCHEDULED   320.0   314.0     NaN  MS RELAPSE 1
# 1331          UNSCHEDULED   659.0   655.0     NaN  MS RELAPSE 2
# 319                   NaN     NaN   211.0   213.0           NaN
# 362                   NaN     NaN   239.0   246.0           NaN
# 2009                  NaN     NaN     NaN     NaN           NaN
# 898              MONTH 24   710.0     NaN     NaN  MS RELAPSE 1
# 872               MONTH 6   176.0    90.0     NaN  MS RELAPSE 1
# 4484          UNSCHEDULED   428.0     NaN     NaN           NaN
# 125                   NaN     NaN    92.0    96.0           NaN
# 4483          UNSCHEDULED   427.0     NaN     NaN           NaN
# 865           UNSCHEDULED    64.0    22.0     NaN  MS RELAPSE 1
# 1336             MONTH 27   807.0     NaN     NaN  MS RELAPSE 2
# 4486          UNSCHEDULED  1031.0     NaN     NaN           NaN
# 1737             MONTH 24   725.0     NaN     NaN           NaN
# 2012                  NaN     NaN     NaN     NaN           NaN
# 212                   NaN     NaN   110.0   144.0           NaN
# 736                   NaN     NaN   628.0   630.0           NaN
# 1732                  NaN     NaN   633.0     NaN           NaN
# 1098          UNSCHEDULED   251.0   245.0     NaN  MS RELAPSE 1
# 413                   NaN     NaN   144.0   267.0           NaN
# 559                   NaN     NaN   379.0   382.0           NaN
# 1721                  NaN     NaN   335.0     NaN           NaN
# 1736             MONTH 18   540.0     NaN     NaN           NaN
# 4485          UNSCHEDULED   470.0     NaN     NaN           NaN
# 1740          UNSCHEDULED   679.0     NaN     NaN           NaN
# 893           UNSCHEDULED   587.0   569.0     NaN  MS RELAPSE 1
# 2077              MONTH 3    92.0     NaN     NaN           NaN
# 890           UNSCHEDULED   520.0   519.0     NaN  MS RELAPSE 1
# 2010                  NaN     NaN     NaN     NaN           NaN
# 887           UNSCHEDULED   482.0   438.0     NaN  MS RELAPSE 1
# 888              MONTH 15   456.0   447.0     NaN  MS RELAPSE 1
# 1738             MONTH 27   806.0     NaN     NaN           NaN
# 671                   NaN     NaN   538.0   543.0           NaN
# 577                   NaN     NaN   398.0   409.0           NaN
# 895           UNSCHEDULED   970.0   953.0     NaN  MS RELAPSE 1
# 1725                  NaN     NaN     NaN     NaN           NaN
# 393                   NaN     NaN     NaN   254.0           NaN
# 635                   NaN     NaN   489.0   494.0           NaN
# 1723                  NaN     NaN   518.0     NaN           NaN
# 886   EARLY/TERMINATION 2   512.0   416.0     NaN  MS RELAPSE 1
# 2467              MONTH 6   176.0     NaN     NaN           NaN
# 880           UNSCHEDULED   296.0   270.0     NaN  MS RELAPSE 1
# 892           UNSCHEDULED   581.0   559.0     NaN  MS RELAPSE 1
# 2014                  NaN     NaN     NaN     NaN           NaN
# 883              MONTH 12   365.0   332.0     NaN  MS RELAPSE 1
# 2011                  NaN     NaN     NaN     NaN           NaN
# 1071          UNSCHEDULED   205.0   200.0     NaN  MS RELAPSE 1
# 1722                  NaN     NaN   344.0     NaN           NaN
# 761                   NaN     NaN   661.0   665.0           NaN
# 871               MONTH 3    85.0    79.0     NaN  MS RELAPSE 1
# 1739          UNSCHEDULED    95.0     NaN     NaN           NaN

# %% [markdown]
# The last five categories seem a bit out of place - is it ok to remove these rows?

# %%
cemodify = clinical_events['CEMODIFY'].dropna()

plt.figure(figsize=(8, 6))
cemodify.value_counts().plot(kind='bar', color='green')
plt.xlabel('CEMODIFY')
plt.ylabel('Count')
plt.title('Bar Chart for CEMODIFY')
plt.show()

# %%
cedecod_counts_clinical_events = clinical_events['CEDECOD'].value_counts().reset_index()
cedecod_counts_clinical_events.columns = ['CEDECOD', 'Count']
print(cedecod_counts_clinical_events) #put everything upper case
# Out:
#                       CEDECOD  Count
# 0  MULTIPLE SCLEROSIS RELAPSE   1505
# 1          RELAPSE-LIKE EVENT    506
# 2          MULTIPLE SCLEROSIS     24
# 3          Multiple sclerosis      1

# %%
clinical_events['CEDECOD'] = clinical_events['CEDECOD'].str.upper()
cedecod_counts_clinical_events = clinical_events['CEDECOD'].value_counts().reset_index()
cedecod_counts_clinical_events.columns = ['CEDECOD', 'Count']
print(cedecod_counts_clinical_events) # DROP
# Out:
#                       CEDECOD  Count
# 0  MULTIPLE SCLEROSIS RELAPSE   1505
# 1          RELAPSE-LIKE EVENT    506
# 2          MULTIPLE SCLEROSIS     25

# %% [markdown]
# - Note: when CETERM is 'POSSIBLE RELAPSE SINCE LAST VISIT', there is no information for CEMODIFY, CEDECOD and CESEV

# %%
clinical_events['CEPRESP'] = clinical_events['CEPRESP'].str.upper()
cepresp_counts_clinical_events = clinical_events['CEPRESP'].value_counts().reset_index()
cepresp_counts_clinical_events.columns = ['CEPRESP', 'Count']
print(cepresp_counts_clinical_events) #drop
# Out:
#   CEPRESP  Count
# 0       Y   2451

# %% [markdown]
# - Note: when CETERM is 'POSSIBLE RELAPSE SINCE LAST VISIT', we have values for CEPRESP and CEOCCUR

# %%
clinical_events['CEOCCUR'] = clinical_events['CEOCCUR'].str.upper()
ceoccur_counts_clinical_events = clinical_events['CEOCCUR'].value_counts().reset_index()
ceoccur_counts_clinical_events.columns = ['CEOCCUR', 'Count']
print(ceoccur_counts_clinical_events)
# Out:
#   CEOCCUR  Count
# 0       N   2354
# 1       Y     97

# %%
clinical_events['CESER'] = clinical_events['CESER'].str.upper()
ceser_counts_clinical_events = clinical_events['CESER'].value_counts().reset_index()
ceser_counts_clinical_events.columns = ['CESER', 'Count']
print(ceser_counts_clinical_events)
# Out:
#   CESER  Count
# 0     N    790
# 1     Y    175

# %%
clinical_events['CEBODSYS'] = clinical_events['CEBODSYS'].str.upper()
cebodsys_counts_clinical_events = clinical_events['CEBODSYS'].value_counts().reset_index()
cebodsys_counts_clinical_events.columns = ['CEBODSYS', 'Count']
print(cebodsys_counts_clinical_events) #drop
# Out:
#                    CEBODSYS  Count
# 0  NERVOUS SYSTEM DISORDERS   1003

# %% [markdown]
# the way this variable exists considering CEMODIFY does not have a clear pattern

# %%
clinical_events['CECONTRT'] = clinical_events['CECONTRT'].str.upper()
cecontrt_counts_clinical_events = clinical_events['CECONTRT'].value_counts().reset_index()
cecontrt_counts_clinical_events.columns = ['CECONTRT', 'Count']
print(cecontrt_counts_clinical_events) # Concomitant or Additional Trtmnt Given - keep
# Out:
#   CECONTRT  Count
# 0        Y    666
# 1        N    185

# %%
cesev_counts_clinical_events = clinical_events['CESEV'].value_counts().reset_index()
cesev_counts_clinical_events.columns = ['CESEV', 'Count']
print(cesev_counts_clinical_events) #severeness of relapse
# Out:
#       CESEV  Count
# 0  MODERATE    989
# 1      MILD    784
# 2    SEVERE    226

# %%
# Pie chart - dropped NA for now
categories = clinical_events['CESEV'].dropna().unique()
category_counts = clinical_events['CESEV'].dropna().value_counts()

plt.pie(category_counts, labels=categories, autopct='%1.1f%%', startangle=90)
plt.legend(labels=categories, loc='lower right', bbox_to_anchor=(1.2, 1))
plt.axis('equal')
plt.show()

# %%
visitnum_counts_clinical_events = clinical_events['VISITNUM'].value_counts().reset_index()
visitnum_counts_clinical_events.columns = ['VISITNUM', 'Count']
print(visitnum_counts_clinical_events)
# Out:
#     VISITNUM  Count
# 0        5.0    297
# 1        6.0    293
# 2        9.0    287
# 3       10.0    282
# 4       12.0    276
# 5       11.0    271
# 6       14.0    267
# 7       13.0    266
# 8      300.0    214
# 9        3.0     50
# 10       4.0     47
# 11       7.0     44
# 12       8.0     44
# 13      15.1     21
# 14     999.0     19
# 15      15.2      8
# 16      15.3      3
# 17      24.0      2
# 18      27.0      2
# 19      18.0      1
# 20      15.0      1
# 21     998.0      1

# %%
visitnum = clinical_events['VISITNUM'].dropna()

plt.figure(figsize=(8, 6))
visitnum.value_counts().plot(kind='bar', color='green')
plt.xlabel('VISITNUM')
plt.ylabel('Count')
plt.title('Bar Chart for VISITNUM')
plt.show()

# %%
visit_counts_clinical_events = clinical_events['VISIT'].value_counts().reset_index()
visit_counts_clinical_events.columns = ['VISIT', 'Count']
print(visit_counts_clinical_events) #same info as VISITNUM it seems
# Out:
#                      VISIT  Count
# 0                  VISIT 5    297
# 1                  VISIT 6    291
# 2                  VISIT 9    287
# 3                 VISIT 10    282
# 4                 VISIT 12    275
# 5                 VISIT 11    271
# 6                 VISIT 14    267
# 7                 VISIT 13    266
# 8         UNSCD RLPSE EVAL    214
# 9                  VISIT 3     48
# 10                 VISIT 4     47
# 11                 VISIT 8     44
# 12                 VISIT 7     44
# 13  EARLY WITHDRAWAL VISIT     21
# 14             UNSCHEDULED     19
# 15      FOLLOW UP MONTH 27      8
# 16         FOLLOW UP VISIT      3
# 17                MONTH 24      2
# 18                 MONTH 6      2
# 19                MONTH 27      2
# 20                 MONTH 3      2
# 21                MONTH 18      1
# 22                MONTH 15      1
# 23     EARLY/TERMINATION 2      1
# 24                MONTH 12      1

# %%
visit = clinical_events['VISIT'].dropna()

plt.figure(figsize=(8, 6))
visit.value_counts().plot(kind='bar', color='green')
plt.xlabel('VISIT')
plt.ylabel('Count')
plt.title('Bar Chart for VISIT')
plt.show()

# %%
mids_counts_clinical_events = clinical_events['MIDS'].value_counts().reset_index()
mids_counts_clinical_events.columns = ['MIDS', 'Count']
print(mids_counts_clinical_events)
# Out:
#            MIDS  Count
# 0  MS RELAPSE 1    852
# 1  MS RELAPSE 2    367
# 2  MS RELAPSE 3    156
# 3  MS RELAPSE 4     75
# 4  MS RELAPSE 5     36
# 5  MS RELAPSE 6     14
# 6  MS RELAPSE 7      3
# 7  MS RELAPSE 8      1
# 8  MS RELAPSE 9      1

# %%
# Pie chart - dropped NA for now
categories = clinical_events['MIDS'].dropna().unique()
category_counts = clinical_events['MIDS'].dropna().value_counts()

plt.pie(category_counts, labels=categories, autopct='%1.1f%%', startangle=90)
plt.legend(labels=categories, loc='lower right', bbox_to_anchor=(1.2, 1))
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Data Transformation

# %%
# remove rows where CEDECOD is MULTIPLE SCLEROSIS -- we do not know if it's a relapse event (confirmed or unconfirmed)
clinical_events = clinical_events[clinical_events['CEDECOD'] != 'MULTIPLE SCLEROSIS']

# %%
# new columns to drop
columns_to_drop_2 = ['VISIT','VISITNUM','CEDECOD','CESTDY','CEENDY','CEDY','CEPRESP','CEBODSYS'] #'MIDS'
#mids already exists in SM dataset and has one more patient
#visit, visitnum, cepresp and cedecod irrelevant
#cedy, cestdy and ceendy not relevant for a static dataset
#cebodsys appearance seems random
clinical_events.drop(columns=columns_to_drop_2, inplace=True)
clinical_events
# Out:
# C:\Users\anaso\AppData\Local\Temp\ipykernel_42928\3760714108.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_events.drop(columns=columns_to_drop_2, inplace=True)
#          USUBJID  CESEQ                             CETERM  \
# 432   MSOAC/0031      1                         MS RELAPSE
# 1334  MSOAC/0031      2                         MS RELAPSE
# 1022  MSOAC/0035      1       MS RELAPSE CONFIRMED BY EDSS
# 1368  MSOAC/0035      2       MS RELAPSE CONFIRMED BY EDSS
# 2375  MSOAC/0041      2  POSSIBLE RELAPSE SINCE LAST VISIT
# ...          ...    ...                                ...
# 1959  MSOAC/9995      4             UNCONFIRMED MS RELAPSE
# 871   MSOAC/9998      1          Confirmed MS Exacerbation
# 1739  MSOAC/9998      2          Suspected MS Exacerbation
# 975   MSOAC/9999      1       MS RELAPSE CONFIRMED BY EDSS
# 1397  MSOAC/9999      2       MS RELAPSE CONFIRMED BY EDSS
#
#                                CEMODIFY CEOCCUR     CESEV CESER CECONTRT  \
# 432       Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1334      Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1022             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 1368             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 2375  POSSIBLE RELAPSE SINCE LAST VISIT       N       NaN   NaN      NaN
# ...                                 ...     ...       ...   ...      ...
# 1959                  Suspected Relapse     NaN      MILD   NaN      NaN
# 871           Confirmed MS Exacerbation     NaN       NaN   NaN        Y
# 1739          Suspected MS Exacerbation     NaN       NaN   NaN        Y
# 975              EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
# 1397             EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
#
#               MIDS
# 432   MS RELAPSE 1
# 1334  MS RELAPSE 2
# 1022  MS RELAPSE 1
# 1368  MS RELAPSE 2
# 2375           NaN
# ...            ...
# 1959           NaN
# 871   MS RELAPSE 1
# 1739           NaN
# 975   MS RELAPSE 1
# 1397  MS RELAPSE 2
#
# [4462 rows x 9 columns]

# %%
# Extract numeric values from 'MIDS' column and convert to integer, replacing NaN with 0 (or any other default value)
clinical_events['Number'] = clinical_events['MIDS'].str.extract(r'(\d+)').astype(float).fillna(0).astype(int)

# Calculate the maximum value within each group defined by 'USUBJID' and create a new column 'NMIDS'
clinical_events['NMIDS'] = clinical_events.groupby('USUBJID')['Number'].transform('max')

clinical_events
# Out:
# C:\Users\anaso\AppData\Local\Temp\ipykernel_42928\2027536413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_events['Number'] = clinical_events['MIDS'].str.extract(r'(\d+)').astype(float).fillna(0).astype(int)
# C:\Users\anaso\AppData\Local\Temp\ipykernel_42928\2027536413.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_events['NMIDS'] = clinical_events.groupby('USUBJID')['Number'].transform('max')
#          USUBJID  CESEQ                             CETERM  \
# 432   MSOAC/0031      1                         MS RELAPSE
# 1334  MSOAC/0031      2                         MS RELAPSE
# 1022  MSOAC/0035      1       MS RELAPSE CONFIRMED BY EDSS
# 1368  MSOAC/0035      2       MS RELAPSE CONFIRMED BY EDSS
# 2375  MSOAC/0041      2  POSSIBLE RELAPSE SINCE LAST VISIT
# ...          ...    ...                                ...
# 1959  MSOAC/9995      4             UNCONFIRMED MS RELAPSE
# 871   MSOAC/9998      1          Confirmed MS Exacerbation
# 1739  MSOAC/9998      2          Suspected MS Exacerbation
# 975   MSOAC/9999      1       MS RELAPSE CONFIRMED BY EDSS
# 1397  MSOAC/9999      2       MS RELAPSE CONFIRMED BY EDSS
#
#                                CEMODIFY CEOCCUR     CESEV CESER CECONTRT  \
# 432       Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1334      Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1022             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 1368             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 2375  POSSIBLE RELAPSE SINCE LAST VISIT       N       NaN   NaN      NaN
# ...                                 ...     ...       ...   ...      ...
# 1959                  Suspected Relapse     NaN      MILD   NaN      NaN
# 871           Confirmed MS Exacerbation     NaN       NaN   NaN        Y
# 1739          Suspected MS Exacerbation     NaN       NaN   NaN        Y
# 975              EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
# 1397             EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
#
#               MIDS  Number  NMIDS
# 432   MS RELAPSE 1       1      2
# 1334  MS RELAPSE 2       2      2
# 1022  MS RELAPSE 1       1      2
# 1368  MS RELAPSE 2       2      2
# 2375           NaN       0      0
# ...            ...     ...    ...
# 1959           NaN       0      2
# 871   MS RELAPSE 1       1      1
# 1739           NaN       0      1
# 975   MS RELAPSE 1       1      2
# 1397  MS RELAPSE 2       2      2
#
# [4462 rows x 11 columns]

# %%
clinical_events_2 = clinical_events.copy()

clinical_events['TOTRELAP'] = clinical_events.groupby('USUBJID')['USUBJID'].transform('count')
clinical_events.drop(columns=['MIDS','Number','CESEQ'], inplace=True)
clinical_events
# Out:
# C:\Users\anaso\AppData\Local\Temp\ipykernel_42928\1087058334.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_events['TOTRELAP'] = clinical_events.groupby('USUBJID')['USUBJID'].transform('count')
# C:\Users\anaso\AppData\Local\Temp\ipykernel_42928\1087058334.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinical_events.drop(columns=['MIDS','Number','CESEQ'], inplace=True)
#          USUBJID                             CETERM  \
# 432   MSOAC/0031                         MS RELAPSE
# 1334  MSOAC/0031                         MS RELAPSE
# 1022  MSOAC/0035       MS RELAPSE CONFIRMED BY EDSS
# 1368  MSOAC/0035       MS RELAPSE CONFIRMED BY EDSS
# 2375  MSOAC/0041  POSSIBLE RELAPSE SINCE LAST VISIT
# ...          ...                                ...
# 1959  MSOAC/9995             UNCONFIRMED MS RELAPSE
# 871   MSOAC/9998          Confirmed MS Exacerbation
# 1739  MSOAC/9998          Suspected MS Exacerbation
# 975   MSOAC/9999       MS RELAPSE CONFIRMED BY EDSS
# 1397  MSOAC/9999       MS RELAPSE CONFIRMED BY EDSS
#
#                                CEMODIFY CEOCCUR     CESEV CESER CECONTRT  \
# 432       Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1334      Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1022             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 1368             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 2375  POSSIBLE RELAPSE SINCE LAST VISIT       N       NaN   NaN      NaN
# ...                                 ...     ...       ...   ...      ...
# 1959                  Suspected Relapse     NaN      MILD   NaN      NaN
# 871           Confirmed MS Exacerbation     NaN       NaN   NaN        Y
# 1739          Suspected MS Exacerbation     NaN       NaN   NaN        Y
# 975              EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
# 1397             EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
#
#       NMIDS  TOTRELAP
# 432       2         2
# 1334      2         2
# 1022      2         2
# 1368      2         2
# 2375      0         4
# ...     ...       ...
# 1959      2         4
# 871       1         2
# 1739      1         2
# 975       2         2
# 1397      2         2
#
# [4462 rows x 9 columns]

# %%
def aggregate_and_remove_duplicates(series):
    unique_values = set(series.dropna())  # Drop NaN and convert to set
    return '; '.join(map(str, unique_values))

clinical_events_aggregated = clinical_events.groupby('USUBJID').agg(aggregate_and_remove_duplicates).reset_index()
#medical_history_aggregated = medical_history.groupby('USUBJID').agg(lambda x: ', '.join(map(str, x))).reset_index()

#clinical_events_aggregated.drop(columns=['MIDS','Number','UCRELAP','CESEQ'], inplace=True)
clinical_events_aggregated.replace('', np.nan, inplace=True)

# Display the aggregated DataFrame
clinical_events_aggregated
# Out:
#          USUBJID                                             CETERM  \
# 0     MSOAC/0031                                         MS RELAPSE
# 1     MSOAC/0035                       MS RELAPSE CONFIRMED BY EDSS
# 2     MSOAC/0041                  POSSIBLE RELAPSE SINCE LAST VISIT
# 3     MSOAC/0044  MS RELAPSE CONFIRMED BY EDSS; UNCONFIRMED MS R...
# 4     MSOAC/0046                                         MS RELAPSE
# ...          ...                                                ...
# 1201  MSOAC/9968                  POSSIBLE RELAPSE SINCE LAST VISIT
# 1202  MSOAC/9981                  POSSIBLE RELAPSE SINCE LAST VISIT
# 1203  MSOAC/9995  MS RELAPSE CONFIRMED BY EDSS; UNCONFIRMED MS R...
# 1204  MSOAC/9998  Suspected MS Exacerbation; Confirmed MS Exacer...
# 1205  MSOAC/9999                       MS RELAPSE CONFIRMED BY EDSS
#
#                                                CEMODIFY CEOCCUR  \
# 0                         Neurologist Confirmed Relapse     NaN
# 1                                EDSS Confirmed Relapse     NaN
# 2                     POSSIBLE RELAPSE SINCE LAST VISIT    N; Y
# 3             Suspected Relapse; EDSS Confirmed Relapse     NaN
# 4             Suspected Relapse; INEC Confirmed Relapse     NaN
# ...                                                 ...     ...
# 1201                  POSSIBLE RELAPSE SINCE LAST VISIT       N
# 1202                  POSSIBLE RELAPSE SINCE LAST VISIT       N
# 1203          Suspected Relapse; EDSS Confirmed Relapse     NaN
# 1204  Suspected MS Exacerbation; Confirmed MS Exacer...     NaN
# 1205                             EDSS Confirmed Relapse     NaN
#
#                CESEV CESER CECONTRT NMIDS TOTRELAP
# 0               MILD     N        Y     2        2
# 1           MODERATE   NaN      NaN     2        2
# 2                NaN   NaN      NaN     0        4
# 3     MODERATE; MILD   NaN      NaN     1        3
# 4           MODERATE  N; Y        Y     1        2
# ...              ...   ...      ...   ...      ...
# 1201             NaN   NaN      NaN     0        8
# 1202             NaN   NaN      NaN     0       12
# 1203            MILD   NaN      NaN     2        4
# 1204             NaN   NaN        Y     1        2
# 1205            MILD   NaN      NaN     2        2
#
# [1206 rows x 9 columns]

# %%
folder_name = 'new_data'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Specify the path for the CSV file
csv_file_path = os.path.join(folder_name, 'ce_agg.csv')

# Save the DataFrame to CSV
clinical_events_aggregated.to_csv(csv_file_path, index=False)

# %% [markdown]
# #### Another idea

# %%
# List of entries to drop
entries_to_drop = ["Multiple Sclerosis", "MULTIPLE SCLEROSIS AGGRAVATED", "PROGRESSION OF MULTIPLE SCLEROSIS", "MULTIPLE SCLEROSIS", "MS-LIKE SYNDROME"]

# Drop rows where 'CEMODIFY' is in the list of entries to drop
clinical_events_2 = clinical_events_2[~clinical_events_2['CEMODIFY'].isin(entries_to_drop)]
clinical_events_2 # está a ir buscar a última versão de clinical events
# Out:
#          USUBJID  CESEQ                             CETERM  \
# 432   MSOAC/0031      1                         MS RELAPSE
# 1334  MSOAC/0031      2                         MS RELAPSE
# 1022  MSOAC/0035      1       MS RELAPSE CONFIRMED BY EDSS
# 1368  MSOAC/0035      2       MS RELAPSE CONFIRMED BY EDSS
# 2375  MSOAC/0041      2  POSSIBLE RELAPSE SINCE LAST VISIT
# ...          ...    ...                                ...
# 1959  MSOAC/9995      4             UNCONFIRMED MS RELAPSE
# 871   MSOAC/9998      1          Confirmed MS Exacerbation
# 1739  MSOAC/9998      2          Suspected MS Exacerbation
# 975   MSOAC/9999      1       MS RELAPSE CONFIRMED BY EDSS
# 1397  MSOAC/9999      2       MS RELAPSE CONFIRMED BY EDSS
#
#                                CEMODIFY CEOCCUR     CESEV CESER CECONTRT  \
# 432       Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1334      Neurologist Confirmed Relapse     NaN      MILD     N        Y
# 1022             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 1368             EDSS Confirmed Relapse     NaN  MODERATE   NaN      NaN
# 2375  POSSIBLE RELAPSE SINCE LAST VISIT       N       NaN   NaN      NaN
# ...                                 ...     ...       ...   ...      ...
# 1959                  Suspected Relapse     NaN      MILD   NaN      NaN
# 871           Confirmed MS Exacerbation     NaN       NaN   NaN        Y
# 1739          Suspected MS Exacerbation     NaN       NaN   NaN        Y
# 975              EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
# 1397             EDSS Confirmed Relapse     NaN      MILD   NaN      NaN
#
#               MIDS  Number  NMIDS
# 432   MS RELAPSE 1       1      2
# 1334  MS RELAPSE 2       2      2
# 1022  MS RELAPSE 1       1      2
# 1368  MS RELAPSE 2       2      2
# 2375           NaN       0      0
# ...            ...     ...    ...
# 1959           NaN       0      2
# 871   MS RELAPSE 1       1      1
# 1739           NaN       0      1
# 975   MS RELAPSE 1       1      2
# 1397  MS RELAPSE 2       2      2
#
# [4462 rows x 11 columns]

# %%
# Convert 'CEMODIFY' column to uppercase
clinical_events_2['CEMODIFY'] = clinical_events_2['CEMODIFY'].str.upper()

# Confirmed Relapses
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['CEMODIFY'].replace('EDSS CONFIRMED RELAPSE', 'CONFIRMED RELAPSE')
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('NEUROLOGIST CONFIRMED RELAPSE', 'CONFIRMED RELAPSE')
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('INEC CONFIRMED RELAPSE', 'CONFIRMED RELAPSE')
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('CONFIRMED MS EXACERBATION', 'CONFIRMED RELAPSE')

# Unconfirmed Relapses
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('SUSPECTED RELAPSE', 'UNCONFIRMED RELAPSE')
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('POSSIBLE RELAPSE SINCE LAST VISIT', 'UNCONFIRMED RELAPSE')
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('SUSPECTED MS EXACERBATION', 'UNCONFIRMED RELAPSE')
clinical_events_2.loc[:, 'UCRELAP'] = clinical_events_2['UCRELAP'].replace('NON-PROTOCOL DEFINED RELAPSE', 'UNCONFIRMED RELAPSE') #the event does not meet the specific criteria for a relapse as outlined in the study protocol.

clinical_events_2
# Out:
#          USUBJID  CESEQ                             CETERM  \
# 432   MSOAC/0031      1                         MS RELAPSE
# 1334  MSOAC/0031      2                         MS RELAPSE
# 1022  MSOAC/0035      1       MS RELAPSE CONFIRMED BY EDSS
# 1368  MSOAC/0035      2       MS RELAPSE CONFIRMED BY EDSS
# 2375  MSOAC/0041      2  POSSIBLE RELAPSE SINCE LAST VISIT
# ...          ...    ...                                ...
# 1959  MSOAC/9995      4             UNCONFIRMED MS RELAPSE
# 871   MSOAC/9998      1          Confirmed MS Exacerbation
# 1739  MSOAC/9998      2          Suspected MS Exacerbation
# 975   MSOAC/9999      1       MS RELAPSE CONFIRMED BY EDSS
# 1397  MSOAC/9999      2       MS RELAPSE CONFIRMED BY EDSS
#
#                                CEMODIFY CEOCCUR     CESEV CESER CECONTRT  \
# 432       NEUROLOGIST CONFIRMED RELAPSE     NaN      MILD     N        Y
# 1334      NEUROLOGIST CONFIRMED RELAPSE     NaN      MILD     N        Y
# 1022             EDSS CONFIRMED RELAPSE     NaN  MODERATE   NaN      NaN
# 1368             EDSS CONFIRMED RELAPSE     NaN  MODERATE   NaN      NaN
# 2375  POSSIBLE RELAPSE SINCE LAST VISIT       N       NaN   NaN      NaN
# ...                                 ...     ...       ...   ...      ...
# 1959                  SUSPECTED RELAPSE     NaN      MILD   NaN      NaN
# 871           CONFIRMED MS EXACERBATION     NaN       NaN   NaN        Y
# 1739          SUSPECTED MS EXACERBATION     NaN       NaN   NaN        Y
# 975              EDSS CONFIRMED RELAPSE     NaN      MILD   NaN      NaN
# 1397             EDSS CONFIRMED RELAPSE     NaN      MILD   NaN      NaN
#
#               MIDS  Number  NMIDS              UCRELAP
# 432   MS RELAPSE 1       1      2    CONFIRMED RELAPSE
# 1334  MS RELAPSE 2       2      2    CONFIRMED RELAPSE
# 1022  MS RELAPSE 1       1      2    CONFIRMED RELAPSE
# 1368  MS RELAPSE 2       2      2    CONFIRMED RELAPSE
# 2375           NaN       0      0  UNCONFIRMED RELAPSE
# ...            ...     ...    ...                  ...
# 1959           NaN       0      2  UNCONFIRMED RELAPSE
# 871   MS RELAPSE 1       1      1    CONFIRMED RELAPSE
# 1739           NaN       0      1  UNCONFIRMED RELAPSE
# 975   MS RELAPSE 1       1      2    CONFIRMED RELAPSE
# 1397  MS RELAPSE 2       2      2    CONFIRMED RELAPSE
#
# [4462 rows x 12 columns]

# %%
ucrelap_counts_clinical_events = clinical_events_2['UCRELAP'].value_counts().reset_index()
ucrelap_counts_clinical_events.columns = ['UCRELAP', 'Count']
print(ucrelap_counts_clinical_events)
# Out:
#                UCRELAP  Count
# 0  UNCONFIRMED RELAPSE   2957
# 1    CONFIRMED RELAPSE   1505

# %%
clinical_events_2['Count'] = 1

# Pivot the table to get counts of each relapse type per patient
pivot_table = pd.pivot_table(clinical_events_2, values='Count', index='USUBJID', columns='UCRELAP', aggfunc='sum', fill_value=0)

# Rename columns
pivot_table.columns = ['CONFR', 'UNCONFR']

# Reset index to make 'USUBJID' a regular column
pivot_table.reset_index(inplace=True)

# Merge the pivot_table with the original DataFrame based on 'USUBJID'
clinical_events_2 = pd.merge(clinical_events_2, pivot_table, on='USUBJID')

# Drop the temporary 'Count' column
clinical_events_2.drop(columns='Count', inplace=True)

clinical_events_2
# Out:
#          USUBJID  CESEQ                             CETERM  \
# 0     MSOAC/0031      1                         MS RELAPSE
# 1     MSOAC/0031      2                         MS RELAPSE
# 2     MSOAC/0035      1       MS RELAPSE CONFIRMED BY EDSS
# 3     MSOAC/0035      2       MS RELAPSE CONFIRMED BY EDSS
# 4     MSOAC/0041      2  POSSIBLE RELAPSE SINCE LAST VISIT
# ...          ...    ...                                ...
# 4457  MSOAC/9995      4             UNCONFIRMED MS RELAPSE
# 4458  MSOAC/9998      1          Confirmed MS Exacerbation
# 4459  MSOAC/9998      2          Suspected MS Exacerbation
# 4460  MSOAC/9999      1       MS RELAPSE CONFIRMED BY EDSS
# 4461  MSOAC/9999      2       MS RELAPSE CONFIRMED BY EDSS
#
#                                CEMODIFY CEOCCUR     CESEV CESER CECONTRT  \
# 0         NEUROLOGIST CONFIRMED RELAPSE     NaN      MILD     N        Y
# 1         NEUROLOGIST CONFIRMED RELAPSE     NaN      MILD     N        Y
# 2                EDSS CONFIRMED RELAPSE     NaN  MODERATE   NaN      NaN
# 3                EDSS CONFIRMED RELAPSE     NaN  MODERATE   NaN      NaN
# 4     POSSIBLE RELAPSE SINCE LAST VISIT       N       NaN   NaN      NaN
# ...                                 ...     ...       ...   ...      ...
# 4457                  SUSPECTED RELAPSE     NaN      MILD   NaN      NaN
# 4458          CONFIRMED MS EXACERBATION     NaN       NaN   NaN        Y
# 4459          SUSPECTED MS EXACERBATION     NaN       NaN   NaN        Y
# 4460             EDSS CONFIRMED RELAPSE     NaN      MILD   NaN      NaN
# 4461             EDSS CONFIRMED RELAPSE     NaN      MILD   NaN      NaN
#
#               MIDS  Number  NMIDS              UCRELAP  CONFR  UNCONFR
# 0     MS RELAPSE 1       1      2    CONFIRMED RELAPSE      2        0
# 1     MS RELAPSE 2       2      2    CONFIRMED RELAPSE      2        0
# 2     MS RELAPSE 1       1      2    CONFIRMED RELAPSE      2        0
# 3     MS RELAPSE 2       2      2    CONFIRMED RELAPSE      2        0
# 4              NaN       0      0  UNCONFIRMED RELAPSE      0        4
# ...            ...     ...    ...                  ...    ...      ...
# 4457           NaN       0      2  UNCONFIRMED RELAPSE      2        2
# 4458  MS RELAPSE 1       1      1    CONFIRMED RELAPSE      1        1
# 4459           NaN       0      1  UNCONFIRMED RELAPSE      1        1
# 4460  MS RELAPSE 1       1      2    CONFIRMED RELAPSE      2        0
# 4461  MS RELAPSE 2       2      2    CONFIRMED RELAPSE      2        0
#
# [4462 rows x 14 columns]

# %%
clinical_events_2['USUBJID'].unique().tolist()
# Out:
# ['MSOAC/0031',
#  'MSOAC/0035',
#  'MSOAC/0041',
#  'MSOAC/0044',
#  'MSOAC/0046',
#  'MSOAC/0050',
#  'MSOAC/0051',
#  'MSOAC/0053',
#  'MSOAC/0057',
#  'MSOAC/0063',
#  'MSOAC/0067',
#  'MSOAC/0070',
#  'MSOAC/0093',
#  'MSOAC/0094',
#  'MSOAC/0095',
#  'MSOAC/0102',
#  'MSOAC/0104',
#  'MSOAC/0110',
#  'MSOAC/0117',
#  'MSOAC/0119',
#  'MSOAC/0125',
#  'MSOAC/0139',
#  'MSOAC/0141',
#  'MSOAC/0149',
#  'MSOAC/0151',
#  'MSOAC/0158',
#  'MSOAC/0165',
#  'MSOAC/0174',
#  'MSOAC/0185',
#  'MSOAC/0186',
#  'MSOAC/0189',
#  'MSOAC/0194',
#  'MSOAC/0197',
#  'MSOAC/0236',
#  'MSOAC/0250',
#  'MSOAC/0251',
#  'MSOAC/0252',
#  'MSOAC/0259',
#  'MSOAC/0275',
#  'MSOAC/0281',
#  'MSOAC/0288',
#  'MSOAC/0295',
#  'MSOAC/0297',
#  'MSOAC/0310',
#  'MSOAC/0315',
#  'MSOAC/0319',
#  'MSOAC/0332',
#  'MSOAC/0354',
#  'MSOAC/0358',
#  'MSOAC/0363',
#  'MSOAC/0368',
#  'MSOAC/0373',
#  'MSOAC/0378',
#  'MSOAC/0381',
#  'MSOAC/0390',
#  'MSOAC/0393',
#  'MSOAC/0395',
#  'MSOAC/0406',
#  'MSOAC/0425',
#  'MSOAC/0432',
#  'MSOAC/0440',
#  'MSOAC/0448',
#  'MSOAC/0449',
#  'MSOAC/0459',
#  'MSOAC/0463',
#  'MSOAC/0473',
#  'MSOAC/0481',
#  'MSOAC/0484',
#  'MSOAC/0495',
#  'MSOAC/0501',
#  'MSOAC/0513',
#  'MSOAC/0516',
#  'MSOAC/0517',
#  'MSOAC/0521',
#  'MSOAC/0522',
#  'MSOAC/0524',
#  'MSOAC/0530',
#  'MSOAC/0566',
#  'MSOAC/0567',
#  'MSOAC/0578',
#  'MSOAC/0581',
#  'MSOAC/0588',
#  'MSOAC/0589',
#  'MSOAC/0600',
#  'MSOAC/0606',
#  'MSOAC/0607',
#  'MSOAC/0608',
#  'MSOAC/0611',
#  'MSOAC/0626',
#  'MSOAC/0650',
#  'MSOAC/0658',
#  'MSOAC/0663',
#  'MSOAC/0665',
#  'MSOAC/0677',
#  'MSOAC/0680',
#  'MSOAC/0689',
#  'MSOAC/0700',
#  'MSOAC/0712',
#  'MSOAC/0714',
#  'MSOAC/0734',
#  'MSOAC/0736',
#  'MSOAC/0747',
#  'MSOAC/0753',
#  'MSOAC/0756',
#  'MSOAC/0758',
#  'MSOAC/0763',
#  'MSOAC/0766',
#  'MSOAC/0779',
#  'MSOAC/0780',
#  'MSOAC/0804',
#  'MSOAC/0808',
#  'MSOAC/0838',
#  'MSOAC/0844',
#  'MSOAC/0859',
#  'MSOAC/0879',
#  'MSOAC/0880',
#  'MSOAC/0885',
#  'MSOAC/0890',
#  'MSOAC/0904',
#  'MSOAC/0910',
#  'MSOAC/0921',
#  'MSOAC/0935',
#  'MSOAC/0954',
#  'MSOAC/0991',
#  'MSOAC/0999',
#  'MSOAC/1000',
#  'MSOAC/1001',
#  'MSOAC/1010',
#  'MSOAC/1019',
#  'MSOAC/1022',
#  'MSOAC/1028',
#  'MSOAC/1032',
#  'MSOAC/1036',
#  'MSOAC/1052',
#  'MSOAC/1056',
#  'MSOAC/1059',
#  'MSOAC/1080',
#  'MSOAC/1082',
#  'MSOAC/1086',
#  'MSOAC/1091',
#  'MSOAC/1093',
#  'MSOAC/1097',
#  'MSOAC/1110',
#  'MSOAC/1118',
#  'MSOAC/1124',
#  'MSOAC/1126',
#  'MSOAC/1129',
#  'MSOAC/1137',
#  'MSOAC/1151',
#  'MSOAC/1163',
#  'MSOAC/1174',
#  'MSOAC/1182',
#  'MSOAC/1187',
#  'MSOAC/1188',
#  'MSOAC/1194',
#  'MSOAC/1196',
#  'MSOAC/1210',
#  'MSOAC/1213',
#  'MSOAC/1215',
#  'MSOAC/1220',
#  'MSOAC/1232',
#  'MSOAC/1237',
#  'MSOAC/1245',
#  'MSOAC/1248',
#  'MSOAC/1255',
#  'MSOAC/1265',
#  'MSOAC/1279',
#  'MSOAC/1283',
#  'MSOAC/1288',
#  'MSOAC/1333',
#  'MSOAC/1343',
#  'MSOAC/1359',
#  'MSOAC/1389',
#  'MSOAC/1406',
#  'MSOAC/1415',
#  'MSOAC/1416',
#  'MSOAC/1422',
#  'MSOAC/1425',
#  'MSOAC/1426',
#  'MSOAC/1439',
#  'MSOAC/1445',
#  'MSOAC/1452',
#  'MSOAC/1459',
#  'MSOAC/1473',
#  'MSOAC/1478',
#  'MSOAC/1492',
#  'MSOAC/1518',
#  'MSOAC/1526',
#  'MSOAC/1538',
#  'MSOAC/1553',
#  'MSOAC/1578',
#  'MSOAC/1579',
#  'MSOAC/1589',
#  'MSOAC/1597',
#  'MSOAC/1601',
#  'MSOAC/1611',
#  'MSOAC/1622',
#  'MSOAC/1626',
#  'MSOAC/1628',
#  'MSOAC/1655',
#  'MSOAC/1656',
#  'MSOAC/1672',
#  'MSOAC/1690',
#  'MSOAC/1691',
#  'MSOAC/1717',
#  'MSOAC/1723',
#  'MSOAC/1728',
#  'MSOAC/1732',
#  'MSOAC/1744',
#  'MSOAC/1746',
#  'MSOAC/1761',
#  'MSOAC/1762',
#  'MSOAC/1767',
#  'MSOAC/1781',
#  'MSOAC/1784',
#  'MSOAC/1799',
#  'MSOAC/1801',
#  'MSOAC/1808',
#  'MSOAC/1811',
#  'MSOAC/1813',
#  'MSOAC/1816',
#  'MSOAC/1821',
#  'MSOAC/1828',
#  'MSOAC/1832',
#  'MSOAC/1836',
#  'MSOAC/1838',
#  'MSOAC/1844',
#  'MSOAC/1853',
#  'MSOAC/1861',
#  'MSOAC/1865',
#  'MSOAC/1867',
#  'MSOAC/1869',
#  'MSOAC/1878',
#  'MSOAC/1879',
#  'MSOAC/1884',
#  'MSOAC/1890',
#  'MSOAC/1892',
#  'MSOAC/1945',
#  'MSOAC/1953',
#  'MSOAC/1965',
#  'MSOAC/1974',
#  'MSOAC/1980',
#  'MSOAC/1983',
#  'MSOAC/1993',
#  'MSOAC/1995',
#  'MSOAC/2010',
#  'MSOAC/2011',
#  'MSOAC/2029',
#  'MSOAC/2041',
#  'MSOAC/2060',
#  'MSOAC/2070',
#  'MSOAC/2082',
#  'MSOAC/2085',
#  'MSOAC/2108',
#  'MSOAC/2121',
#  'MSOAC/2123',
#  'MSOAC/2134',
#  'MSOAC/2144',
#  'MSOAC/2145',
#  'MSOAC/2149',
#  'MSOAC/2151',
#  'MSOAC/2158',
#  'MSOAC/2177',
#  'MSOAC/2202',
#  'MSOAC/2208',
#  'MSOAC/2211',
#  'MSOAC/2218',
#  'MSOAC/2231',
#  'MSOAC/2237',
#  'MSOAC/2250',
#  'MSOAC/2267',
#  'MSOAC/2270',
#  'MSOAC/2279',
#  'MSOAC/2290',
#  'MSOAC/2300',
#  'MSOAC/2301',
#  'MSOAC/2316',
#  'MSOAC/2317',
#  'MSOAC/2327',
#  'MSOAC/2329',
#  'MSOAC/2332',
#  'MSOAC/2350',
#  'MSOAC/2353',
#  'MSOAC/2374',
#  'MSOAC/2379',
#  'MSOAC/2394',
#  'MSOAC/2402',
#  'MSOAC/2417',
#  'MSOAC/2421',
#  'MSOAC/2424',
#  'MSOAC/2430',
#  'MSOAC/2438',
#  'MSOAC/2453',
#  'MSOAC/2456',
#  'MSOAC/2457',
#  'MSOAC/2463',
#  'MSOAC/2476',
#  'MSOAC/2478',
#  'MSOAC/2498',
#  'MSOAC/2501',
#  'MSOAC/2502',
#  'MSOAC/2510',
#  'MSOAC/2534',
#  'MSOAC/2544',
#  'MSOAC/2548',
#  'MSOAC/2569',
#  'MSOAC/2570',
#  'MSOAC/2572',
#  'MSOAC/2580',
#  'MSOAC/2602',
#  'MSOAC/2617',
#  'MSOAC/2626',
#  'MSOAC/2651',
#  'MSOAC/2654',
#  'MSOAC/2658',
#  'MSOAC/2660',
#  'MSOAC/2661',
#  'MSOAC/2662',
#  'MSOAC/2670',
#  'MSOAC/2692',
#  'MSOAC/2698',
#  'MSOAC/2699',
#  'MSOAC/2701',
#  'MSOAC/2712',
#  'MSOAC/2714',
#  'MSOAC/2719',
#  'MSOAC/2721',
#  'MSOAC/2737',
#  'MSOAC/2741',
#  'MSOAC/2745',
#  'MSOAC/2753',
#  'MSOAC/2754',
#  'MSOAC/2757',
#  'MSOAC/2763',
#  'MSOAC/2790',
#  'MSOAC/2792',
#  'MSOAC/2795',
#  'MSOAC/2796',
#  'MSOAC/2800',
#  'MSOAC/2808',
#  'MSOAC/2832',
#  'MSOAC/2841',
#  'MSOAC/2842',
#  'MSOAC/2848',
#  'MSOAC/2851',
#  'MSOAC/2863',
#  'MSOAC/2874',
#  'MSOAC/2891',
#  'MSOAC/2904',
#  'MSOAC/2910',
#  'MSOAC/2918',
#  'MSOAC/2927',
#  'MSOAC/2951',
#  'MSOAC/2959',
#  'MSOAC/2961',
#  'MSOAC/2963',
#  'MSOAC/2965',
#  'MSOAC/2966',
#  'MSOAC/2967',
#  'MSOAC/2971',
#  'MSOAC/3004',
#  'MSOAC/3006',
#  'MSOAC/3010',
#  'MSOAC/3012',
#  'MSOAC/3013',
#  'MSOAC/3014',
#  'MSOAC/3018',
#  'MSOAC/3028',
#  'MSOAC/3037',
#  'MSOAC/3047',
#  'MSOAC/3058',
#  'MSOAC/3077',
#  'MSOAC/3091',
#  'MSOAC/3094',
#  'MSOAC/3111',
#  'MSOAC/3121',
#  'MSOAC/3127',
#  'MSOAC/3128',
#  'MSOAC/3133',
#  'MSOAC/3151',
#  'MSOAC/3159',
#  'MSOAC/3162',
#  'MSOAC/3166',
#  'MSOAC/3179',
#  'MSOAC/3185',
#  'MSOAC/3187',
#  'MSOAC/3196',
#  'MSOAC/3200',
#  'MSOAC/3202',
#  'MSOAC/3203',
#  'MSOAC/3231',
#  'MSOAC/3235',
#  'MSOAC/3236',
#  'MSOAC/3247',
#  'MSOAC/3268',
#  'MSOAC/3291',
#  'MSOAC/3294',
#  'MSOAC/3327',
#  'MSOAC/3337',
#  'MSOAC/3346',
#  'MSOAC/3351',
#  'MSOAC/3355',
#  'MSOAC/3362',
#  'MSOAC/3368',
#  'MSOAC/3373',
#  'MSOAC/3392',
#  'MSOAC/3395',
#  'MSOAC/3421',
#  'MSOAC/3433',
#  'MSOAC/3441',
#  'MSOAC/3445',
#  'MSOAC/3446',
#  'MSOAC/3447',
#  'MSOAC/3449',
#  'MSOAC/3463',
#  'MSOAC/3472',
#  'MSOAC/3491',
#  'MSOAC/3500',
#  'MSOAC/3519',
#  'MSOAC/3520',
#  'MSOAC/3522',
#  'MSOAC/3523',
#  'MSOAC/3529',
#  'MSOAC/3530',
#  'MSOAC/3534',
#  'MSOAC/3543',
#  'MSOAC/3547',
#  'MSOAC/3562',
#  'MSOAC/3571',
#  'MSOAC/3579',
#  'MSOAC/3581',
#  'MSOAC/3582',
#  'MSOAC/3596',
#  'MSOAC/3605',
#  'MSOAC/3620',
#  'MSOAC/3626',
#  'MSOAC/3629',
#  'MSOAC/3634',
#  'MSOAC/3640',
#  'MSOAC/3642',
#  'MSOAC/3663',
#  'MSOAC/3669',
#  'MSOAC/3676',
#  'MSOAC/3683',
#  'MSOAC/3687',
#  'MSOAC/3694',
#  'MSOAC/3705',
#  'MSOAC/3710',
#  'MSOAC/3718',
#  'MSOAC/3724',
#  'MSOAC/3737',
#  'MSOAC/3738',
#  'MSOAC/3753',
#  'MSOAC/3773',
#  'MSOAC/3780',
#  'MSOAC/3782',
#  'MSOAC/3804',
#  'MSOAC/3809',
#  'MSOAC/3823',
#  'MSOAC/3825',
#  'MSOAC/3832',
#  'MSOAC/3851',
#  'MSOAC/3855',
#  'MSOAC/3861',
#  'MSOAC/3870',
#  'MSOAC/3874',
#  'MSOAC/3884',
#  'MSOAC/3917',
#  'MSOAC/3921',
#  'MSOAC/3925',
#  'MSOAC/3930',
#  'MSOAC/3933',
#  'MSOAC/3934',
#  'MSOAC/3936',
#  'MSOAC/3953',
#  'MSOAC/3960',
#  'MSOAC/3974',
#  'MSOAC/3988',
#  'MSOAC/3989',
#  'MSOAC/3995',
#  'MSOAC/3996',
#  'MSOAC/4001',
#  'MSOAC/4008',
#  'MSOAC/4010',
#  'MSOAC/4029',
#  'MSOAC/4030',
#  'MSOAC/4036',
#  'MSOAC/4037',
#  'MSOAC/4047',
#  'MSOAC/4072',
#  'MSOAC/4084',
#  'MSOAC/4094',
#  'MSOAC/4095',
#  'MSOAC/4102',
#  'MSOAC/4104',
#  'MSOAC/4108',
#  'MSOAC/4111',
#  'MSOAC/4116',
#  'MSOAC/4129',
#  'MSOAC/4145',
#  'MSOAC/4151',
#  'MSOAC/4153',
#  'MSOAC/4157',
#  'MSOAC/4158',
#  'MSOAC/4165',
#  'MSOAC/4168',
#  'MSOAC/4174',
#  'MSOAC/4185',
#  'MSOAC/4188',
#  'MSOAC/4204',
#  'MSOAC/4208',
#  'MSOAC/4209',
#  'MSOAC/4212',
#  'MSOAC/4213',
#  'MSOAC/4214',
#  'MSOAC/4215',
#  'MSOAC/4239',
#  'MSOAC/4252',
#  'MSOAC/4255',
#  'MSOAC/4266',
#  'MSOAC/4268',
#  'MSOAC/4274',
#  'MSOAC/4285',
#  'MSOAC/4287',
#  'MSOAC/4288',
#  'MSOAC/4300',
#  'MSOAC/4307',
#  'MSOAC/4313',
#  'MSOAC/4320',
#  'MSOAC/4334',
#  'MSOAC/4352',
#  'MSOAC/4362',
#  'MSOAC/4391',
#  'MSOAC/4394',
#  'MSOAC/4395',
#  'MSOAC/4396',
#  'MSOAC/4402',
#  'MSOAC/4417',
#  'MSOAC/4419',
#  'MSOAC/4430',
#  'MSOAC/4431',
#  'MSOAC/4468',
#  'MSOAC/4479',
#  'MSOAC/4481',
#  'MSOAC/4482',
#  'MSOAC/4484',
#  'MSOAC/4486',
#  'MSOAC/4487',
#  'MSOAC/4495',
#  'MSOAC/4512',
#  'MSOAC/4535',
#  'MSOAC/4538',
#  'MSOAC/4540',
#  'MSOAC/4555',
#  'MSOAC/4561',
#  'MSOAC/4567',
#  'MSOAC/4576',
#  'MSOAC/4582',
#  'MSOAC/4589',
#  'MSOAC/4596',
#  'MSOAC/4603',
#  'MSOAC/4604',
#  'MSOAC/4610',
#  'MSOAC/4612',
#  'MSOAC/4614',
#  'MSOAC/4625',
#  'MSOAC/4633',
#  'MSOAC/4636',
#  'MSOAC/4651',
#  'MSOAC/4660',
#  'MSOAC/4665',
#  'MSOAC/4671',
#  'MSOAC/4703',
#  'MSOAC/4708',
#  'MSOAC/4712',
#  'MSOAC/4713',
#  'MSOAC/4719',
#  'MSOAC/4722',
#  'MSOAC/4730',
#  'MSOAC/4736',
#  'MSOAC/4737',
#  'MSOAC/4739',
#  'MSOAC/4745',
#  'MSOAC/4758',
#  'MSOAC/4760',
#  'MSOAC/4775',
#  'MSOAC/4781',
#  'MSOAC/4785',
#  'MSOAC/4796',
#  'MSOAC/4801',
#  'MSOAC/4802',
#  'MSOAC/4818',
#  'MSOAC/4827',
#  'MSOAC/4834',
#  'MSOAC/4835',
#  'MSOAC/4845',
#  'MSOAC/4856',
#  'MSOAC/4863',
#  'MSOAC/4864',
#  'MSOAC/4865',
#  'MSOAC/4866',
#  'MSOAC/4873',
#  'MSOAC/4879',
#  'MSOAC/4889',
#  'MSOAC/4925',
#  'MSOAC/4939',
#  'MSOAC/4947',
#  'MSOAC/4955',
#  'MSOAC/4957',
#  'MSOAC/4967',
#  'MSOAC/4981',
#  'MSOAC/4983',
#  'MSOAC/4989',
#  'MSOAC/5000',
#  'MSOAC/5001',
#  'MSOAC/5008',
#  'MSOAC/5012',
#  'MSOAC/5031',
#  'MSOAC/5046',
#  'MSOAC/5075',
#  'MSOAC/5108',
#  'MSOAC/5113',
#  'MSOAC/5136',
#  'MSOAC/5137',
#  'MSOAC/5142',
#  'MSOAC/5156',
#  'MSOAC/5180',
#  'MSOAC/5206',
#  'MSOAC/5208',
#  'MSOAC/5241',
#  'MSOAC/5244',
#  'MSOAC/5245',
#  'MSOAC/5251',
#  'MSOAC/5252',
#  'MSOAC/5261',
#  'MSOAC/5287',
#  'MSOAC/5308',
#  'MSOAC/5326',
#  'MSOAC/5341',
#  'MSOAC/5343',
#  'MSOAC/5351',
#  'MSOAC/5354',
#  'MSOAC/5358',
#  'MSOAC/5359',
#  'MSOAC/5361',
#  'MSOAC/5363',
#  'MSOAC/5371',
#  'MSOAC/5396',
#  'MSOAC/5413',
#  'MSOAC/5435',
#  'MSOAC/5459',
#  'MSOAC/5466',
#  'MSOAC/5472',
#  'MSOAC/5474',
#  'MSOAC/5475',
#  'MSOAC/5482',
#  'MSOAC/5484',
#  'MSOAC/5486',
#  'MSOAC/5494',
#  'MSOAC/5499',
#  'MSOAC/5501',
#  'MSOAC/5505',
#  'MSOAC/5507',
#  'MSOAC/5532',
#  'MSOAC/5539',
#  'MSOAC/5546',
#  'MSOAC/5550',
#  'MSOAC/5552',
#  'MSOAC/5553',
#  'MSOAC/5558',
#  'MSOAC/5559',
#  'MSOAC/5576',
#  'MSOAC/5580',
#  'MSOAC/5585',
#  'MSOAC/5590',
#  'MSOAC/5602',
#  'MSOAC/5603',
#  'MSOAC/5612',
#  'MSOAC/5617',
#  'MSOAC/5634',
#  'MSOAC/5703',
#  'MSOAC/5705',
#  'MSOAC/5710',
#  'MSOAC/5712',
#  'MSOAC/5725',
#  'MSOAC/5727',
#  'MSOAC/5731',
#  'MSOAC/5735',
#  'MSOAC/5737',
#  'MSOAC/5739',
#  'MSOAC/5754',
#  'MSOAC/5757',
#  'MSOAC/5764',
#  'MSOAC/5774',
#  'MSOAC/5776',
#  'MSOAC/5778',
#  'MSOAC/5780',
#  'MSOAC/5795',
#  'MSOAC/5804',
#  'MSOAC/5817',
#  'MSOAC/5827',
#  'MSOAC/5829',
#  'MSOAC/5853',
#  'MSOAC/5873',
#  'MSOAC/5877',
#  'MSOAC/5885',
#  'MSOAC/5891',
#  'MSOAC/5893',
#  'MSOAC/5913',
#  'MSOAC/5915',
#  'MSOAC/5938',
#  'MSOAC/5942',
#  'MSOAC/5950',
#  'MSOAC/5952',
#  'MSOAC/5953',
#  'MSOAC/5971',
#  'MSOAC/5973',
#  'MSOAC/5975',
#  'MSOAC/5977',
#  'MSOAC/5983',
#  'MSOAC/6016',
#  'MSOAC/6018',
#  'MSOAC/6019',
#  'MSOAC/6028',
#  'MSOAC/6038',
#  'MSOAC/6042',
#  'MSOAC/6059',
#  'MSOAC/6064',
#  'MSOAC/6072',
#  'MSOAC/6078',
#  'MSOAC/6091',
#  'MSOAC/6093',
#  'MSOAC/6096',
#  'MSOAC/6099',
#  'MSOAC/6108',
#  'MSOAC/6113',
#  'MSOAC/6116',
#  'MSOAC/6171',
#  'MSOAC/6179',
#  'MSOAC/6186',
#  'MSOAC/6190',
#  'MSOAC/6201',
#  'MSOAC/6210',
#  'MSOAC/6211',
#  'MSOAC/6218',
#  'MSOAC/6228',
#  'MSOAC/6234',
#  'MSOAC/6247',
#  'MSOAC/6249',
#  'MSOAC/6252',
#  'MSOAC/6260',
#  'MSOAC/6267',
#  'MSOAC/6273',
#  'MSOAC/6279',
#  'MSOAC/6289',
#  'MSOAC/6290',
#  'MSOAC/6296',
#  'MSOAC/6297',
#  'MSOAC/6307',
#  'MSOAC/6311',
#  'MSOAC/6315',
#  'MSOAC/6317',
#  'MSOAC/6321',
#  'MSOAC/6326',
#  'MSOAC/6327',
#  'MSOAC/6328',
#  'MSOAC/6329',
#  'MSOAC/6334',
#  'MSOAC/6336',
#  'MSOAC/6349',
#  'MSOAC/6351',
#  'MSOAC/6352',
#  'MSOAC/6370',
#  'MSOAC/6371',
#  'MSOAC/6375',
#  'MSOAC/6383',
#  'MSOAC/6389',
#  'MSOAC/6391',
#  'MSOAC/6402',
#  'MSOAC/6411',
#  'MSOAC/6417',
#  'MSOAC/6421',
#  'MSOAC/6429',
#  'MSOAC/6430',
#  'MSOAC/6457',
#  'MSOAC/6472',
#  'MSOAC/6473',
#  'MSOAC/6476',
#  'MSOAC/6477',
#  'MSOAC/6479',
#  'MSOAC/6480',
#  'MSOAC/6484',
#  'MSOAC/6496',
#  'MSOAC/6497',
#  'MSOAC/6507',
#  'MSOAC/6511',
#  'MSOAC/6514',
#  'MSOAC/6540',
#  'MSOAC/6559',
#  'MSOAC/6576',
#  'MSOAC/6587',
#  'MSOAC/6595',
#  'MSOAC/6603',
#  'MSOAC/6610',
#  'MSOAC/6624',
#  'MSOAC/6628',
#  'MSOAC/6636',
#  'MSOAC/6642',
#  'MSOAC/6648',
#  'MSOAC/6659',
#  'MSOAC/6673',
#  'MSOAC/6690',
#  'MSOAC/6698',
#  'MSOAC/6719',
#  'MSOAC/6720',
#  'MSOAC/6728',
#  'MSOAC/6734',
#  'MSOAC/6742',
#  'MSOAC/6747',
#  'MSOAC/6748',
#  'MSOAC/6751',
#  'MSOAC/6753',
#  'MSOAC/6764',
#  'MSOAC/6781',
#  'MSOAC/6788',
#  'MSOAC/6801',
#  'MSOAC/6807',
#  'MSOAC/6811',
#  'MSOAC/6815',
#  'MSOAC/6821',
#  'MSOAC/6823',
#  'MSOAC/6833',
#  'MSOAC/6837',
#  'MSOAC/6840',
#  'MSOAC/6849',
#  'MSOAC/6857',
#  'MSOAC/6862',
#  'MSOAC/6872',
#  'MSOAC/6874',
#  'MSOAC/6876',
#  'MSOAC/6886',
#  'MSOAC/6902',
#  'MSOAC/6907',
#  'MSOAC/6912',
#  'MSOAC/6917',
#  'MSOAC/6934',
#  'MSOAC/6938',
#  'MSOAC/6942',
#  'MSOAC/6951',
#  'MSOAC/6952',
#  'MSOAC/6954',
#  'MSOAC/6964',
#  'MSOAC/6969',
#  'MSOAC/6974',
#  'MSOAC/6975',
#  'MSOAC/6979',
#  'MSOAC/6981',
#  'MSOAC/6984',
#  'MSOAC/6987',
#  'MSOAC/6988',
#  'MSOAC/7002',
#  'MSOAC/7006',
#  'MSOAC/7011',
#  'MSOAC/7014',
#  'MSOAC/7020',
#  'MSOAC/7043',
#  'MSOAC/7048',
#  'MSOAC/7075',
#  'MSOAC/7084',
#  'MSOAC/7101',
#  'MSOAC/7106',
#  'MSOAC/7107',
#  'MSOAC/7108',
#  'MSOAC/7141',
#  'MSOAC/7147',
#  'MSOAC/7159',
#  'MSOAC/7166',
#  'MSOAC/7194',
#  'MSOAC/7199',
#  'MSOAC/7202',
#  'MSOAC/7206',
#  'MSOAC/7212',
#  'MSOAC/7222',
#  'MSOAC/7236',
#  'MSOAC/7238',
#  'MSOAC/7250',
#  'MSOAC/7251',
#  'MSOAC/7267',
#  'MSOAC/7268',
#  'MSOAC/7269',
#  'MSOAC/7271',
#  'MSOAC/7280',
#  'MSOAC/7286',
#  'MSOAC/7289',
#  'MSOAC/7329',
#  'MSOAC/7341',
#  'MSOAC/7342',
#  'MSOAC/7343',
#  'MSOAC/7346',
#  'MSOAC/7354',
#  'MSOAC/7363',
#  'MSOAC/7400',
#  'MSOAC/7402',
#  'MSOAC/7413',
#  'MSOAC/7419',
#  'MSOAC/7430',
#  'MSOAC/7439',
#  'MSOAC/7441',
#  'MSOAC/7448',
#  'MSOAC/7458',
#  'MSOAC/7475',
#  'MSOAC/7485',
#  'MSOAC/7492',
#  'MSOAC/7495',
#  'MSOAC/7497',
#  'MSOAC/7501',
#  'MSOAC/7502',
#  'MSOAC/7507',
#  'MSOAC/7511',
#  'MSOAC/7522',
#  'MSOAC/7526',
#  'MSOAC/7532',
#  'MSOAC/7547',
#  'MSOAC/7550',
#  'MSOAC/7551',
#  'MSOAC/7576',
#  'MSOAC/7579',
#  'MSOAC/7593',
#  'MSOAC/7596',
#  'MSOAC/7608',
#  'MSOAC/7613',
#  'MSOAC/7635',
#  'MSOAC/7662',
#  'MSOAC/7663',
#  'MSOAC/7685',
#  'MSOAC/7692',
#  'MSOAC/7696',
#  'MSOAC/7715',
#  'MSOAC/7727',
#  'MSOAC/7738',
#  'MSOAC/7742',
#  'MSOAC/7753',
#  'MSOAC/7770',
#  'MSOAC/7776',
#  'MSOAC/7779',
#  'MSOAC/7780',
#  'MSOAC/7790',
#  'MSOAC/7794',
#  'MSOAC/7797',
#  'MSOAC/7802',
#  'MSOAC/7809',
#  'MSOAC/7810',
#  'MSOAC/7815',
#  'MSOAC/7818',
#  'MSOAC/7829',
#  'MSOAC/7843',
#  'MSOAC/7846',
#  'MSOAC/7877',
#  'MSOAC/7886',
#  'MSOAC/7888',
#  'MSOAC/7898',
#  'MSOAC/7904',
#  'MSOAC/7920',
#  'MSOAC/7922',
#  'MSOAC/7924',
#  'MSOAC/7930',
#  'MSOAC/7942',
#  'MSOAC/7944',
#  'MSOAC/7954',
#  'MSOAC/7958',
#  'MSOAC/7974',
#  'MSOAC/7985',
#  'MSOAC/7986',
#  'MSOAC/8001',
#  'MSOAC/8002',
#  'MSOAC/8005',
#  'MSOAC/8021',
#  'MSOAC/8028',
#  'MSOAC/8034',
#  'MSOAC/8040',
#  'MSOAC/8057',
#  'MSOAC/8069',
#  'MSOAC/8077',
#  'MSOAC/8079',
#  'MSOAC/8083',
#  'MSOAC/8104',
#  'MSOAC/8117',
#  'MSOAC/8122',
#  'MSOAC/8124',
#  'MSOAC/8126',
#  'MSOAC/8127',
#  'MSOAC/8148',
#  'MSOAC/8153',
#  'MSOAC/8165',
#  'MSOAC/8167',
#  'MSOAC/8169',
#  'MSOAC/8173',
#  'MSOAC/8178',
#  'MSOAC/8189',
#  'MSOAC/8193',
#  ...]

# %%
clinical_events_2[clinical_events_2['USUBJID'] == 'MSOAC/8193']
# Out:
#          USUBJID  CESEQ                        CETERM                CEMODIFY  \
# 3687  MSOAC/8193      1  MS RELAPSE CONFIRMED BY EDSS  EDSS CONFIRMED RELAPSE
# 3688  MSOAC/8193      2  MS RELAPSE CONFIRMED BY EDSS  EDSS CONFIRMED RELAPSE
#
#      CEOCCUR     CESEV CESER CECONTRT          MIDS  Number  NMIDS  \
# 3687     NaN    SEVERE   NaN      NaN  MS RELAPSE 1       1      2
# 3688     NaN  MODERATE   NaN      NaN  MS RELAPSE 2       2      2
#
#                 UCRELAP  CONFR  UNCONFR
# 3687  CONFIRMED RELAPSE      2        0
# 3688  CONFIRMED RELAPSE      2        0

# %%
def aggregate_and_remove_duplicates(series):
    unique_values = set(series.dropna())  # Drop NaN and convert to set
    return '; '.join(map(str, unique_values))

clinical_events_aggregated_2 = clinical_events_2.groupby('USUBJID').agg(aggregate_and_remove_duplicates).reset_index()
#medical_history_aggregated = medical_history.groupby('USUBJID').agg(lambda x: ', '.join(map(str, x))).reset_index()

clinical_events_aggregated_2.drop(columns=['MIDS','Number','UCRELAP','CESEQ'], inplace=True)
clinical_events_aggregated_2.replace('', np.nan, inplace=True)

# Display the aggregated DataFrame
clinical_events_aggregated_2
# Out:
#          USUBJID                                             CETERM  \
# 0     MSOAC/0031                                         MS RELAPSE
# 1     MSOAC/0035                       MS RELAPSE CONFIRMED BY EDSS
# 2     MSOAC/0041                  POSSIBLE RELAPSE SINCE LAST VISIT
# 3     MSOAC/0044  MS RELAPSE CONFIRMED BY EDSS; UNCONFIRMED MS R...
# 4     MSOAC/0046                                         MS RELAPSE
# ...          ...                                                ...
# 1201  MSOAC/9968                  POSSIBLE RELAPSE SINCE LAST VISIT
# 1202  MSOAC/9981                  POSSIBLE RELAPSE SINCE LAST VISIT
# 1203  MSOAC/9995  MS RELAPSE CONFIRMED BY EDSS; UNCONFIRMED MS R...
# 1204  MSOAC/9998  Suspected MS Exacerbation; Confirmed MS Exacer...
# 1205  MSOAC/9999                       MS RELAPSE CONFIRMED BY EDSS
#
#                                                CEMODIFY CEOCCUR  \
# 0                         NEUROLOGIST CONFIRMED RELAPSE     NaN
# 1                                EDSS CONFIRMED RELAPSE     NaN
# 2                     POSSIBLE RELAPSE SINCE LAST VISIT    N; Y
# 3             EDSS CONFIRMED RELAPSE; SUSPECTED RELAPSE     NaN
# 4             INEC CONFIRMED RELAPSE; SUSPECTED RELAPSE     NaN
# ...                                                 ...     ...
# 1201                  POSSIBLE RELAPSE SINCE LAST VISIT       N
# 1202                  POSSIBLE RELAPSE SINCE LAST VISIT       N
# 1203          EDSS CONFIRMED RELAPSE; SUSPECTED RELAPSE     NaN
# 1204  CONFIRMED MS EXACERBATION; SUSPECTED MS EXACER...     NaN
# 1205                             EDSS CONFIRMED RELAPSE     NaN
#
#                CESEV CESER CECONTRT NMIDS CONFR UNCONFR
# 0               MILD     N        Y     2     2       0
# 1           MODERATE   NaN      NaN     2     2       0
# 2                NaN   NaN      NaN     0     0       4
# 3     MODERATE; MILD   NaN      NaN     1     1       2
# 4           MODERATE  N; Y        Y     1     1       1
# ...              ...   ...      ...   ...   ...     ...
# 1201             NaN   NaN      NaN     0     0       8
# 1202             NaN   NaN      NaN     0     0      12
# 1203            MILD   NaN      NaN     2     2       2
# 1204             NaN   NaN        Y     1     1       1
# 1205            MILD   NaN      NaN     2     2       0
#
# [1206 rows x 10 columns]

# %%
columns_match = (clinical_events_aggregated_2['NMIDS'] == clinical_events_aggregated_2['CONFR']).all()
columns_match
# Out:
# True

# %%
missing_percentage_ceagg = (clinical_events_aggregated_2.isnull().sum() / len(clinical_events_aggregated_2)) * 100
missing_clinical_events_aggregated = pd.DataFrame({'Column Name': missing_percentage_ceagg.index, 'Missing Percentage': missing_percentage_ceagg.values})
missing_clinical_events_aggregated = missing_clinical_events_aggregated.sort_values(by='Missing Percentage', ascending=False)
print(missing_clinical_events_aggregated)
# Out:
#   Column Name  Missing Percentage
# 3     CEOCCUR           74.792703
# 6    CECONTRT           64.842454
# 5       CESER           61.194030
# 4       CESEV           22.056385
# 0     USUBJID            0.000000
# 1      CETERM            0.000000
# 2    CEMODIFY            0.000000
# 7       NMIDS            0.000000
# 8       CONFR            0.000000
# 9     UNCONFR            0.000000

# %%
#folder_name = 'new_data'
#if not os.path.exists(folder_name):
#    os.makedirs(folder_name)

## Specify the path for the CSV file
#csv_file_path = os.path.join(folder_name, 'ce2_agg.csv')

## Save the DataFrame to CSV
#clinical_events_aggregated_2.to_csv(csv_file_path, index=False)

# %% [markdown]
# #### **Ideas**:
# - MIDS column associated to MIDS column in milestones
# - use CESEV column as output or input
# - check ce_analysis.png!! some variables seem to complement each other
# - CEDECOD organizes CEMODIFY, and CEMODIFY organizes CETERM (in way less categories)!!! -- *explore more these 3 columns*
# - remove CEBODSYS since is only one category?
# - for MIDS: maybe group when relapses are 5 or more
#     - also create new column where for each patient i say the number of relapses (MIDSMAX)
# - VISITNUM is kind of a code number for VISIT, they give the same info
